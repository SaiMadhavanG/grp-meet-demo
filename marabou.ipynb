# %% [markdown]
# ## Installation
#
# Warning: current version of `maraboupy` is not supported on Windows

# %%
# !pip3 install maraboupy
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: maraboupy in /home/saimadhavang/.local/lib/python3.10/site-packages (2.0.0)

# %% [markdown]
# #### Importing Necessary Packages

# %%
import json
import numpy as np
from maraboupy import Marabou, MarabouCore, MarabouUtils
import pandas
from torchvision import transforms, datasets
from torch.utils.data import DataLoader
from tqdm.auto import tqdm
# Out:
# /home/saimadhavang/.local/lib/python3.10/site-packages/maraboupy/Marabou.py:27: UserWarning: Tensorflow parser is unavailable because tensorflow package is not installed
#   warnings.warn("Tensorflow parser is unavailable because tensorflow package is not installed")

# %% [markdown]
# ## Global Variables
#
# You can set values to the following global variables depending on your desired configuration.
#
# - `NET_PATH`: Path to the model trained on MNIST, in ONNX format
# - `MAX_TIME`: Maximum time (in seconds) before a particular instance is timed out
# - `START` and `END`: Images corresponding to the indices between `START` and `END` in the MNIST test data will be considered for verification
# - `EPSILON`: $\epsilon$ of $\ell_\infty$ norm around each instance

# %%
NET_PATH = 'mnist_fc.onnx'
MAX_TIME = 30
START = 0
END = 20
EPSILON = 0.2

M_OPTIONS: MarabouCore.Options = Marabou.createOptions(verbosity=0, timeoutInSeconds=MAX_TIME)

# %% [markdown]
# `init_network` initializes the network by loading it and establishing lower and upper bounds for each input neuron depending on the datapoint and the value of $\epsilon$

# %%
def init_network(data_point=None, epsilon=None)->Marabou.MarabouNetworkNNet:

    network:Marabou.MarabouNetworkNNet = Marabou.read_onnx(NET_PATH)
    
    for i in range(784):
        network.setLowerBound(i, max(data_point[i]-epsilon, 0.))
        network.setUpperBound(i, min(data_point[i]+epsilon, 1.))
  
    return network

# %% [markdown]
# `add_counter_example_constraint` is responsible for adding a constraint on the output that dictates value of `other_label` should be greater than value of `label`.
#
# This way, if we get a `SAT`, we can conclude a counter example has been found; if we get an `UNSAT`, the example has been safely verified

# %%
def add_counter_example_constraint(network, label, other_label):

    offset = network.outputVars[0][0][0]

    constraint = MarabouUtils.Equation(MarabouCore.Equation.GE)
    constraint.addAddend(1, other_label+offset)
    constraint.addAddend(-1, label+offset)
    constraint.setScalar(0.0001)

    network.addEquation(constraint)

    return network

# %% [markdown]
# Loading and processing data

# %%
transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize((0.,), (1.,))
])

trainset = datasets.MNIST(root='./data', train=False, download=True, transform=transform)
testloader = DataLoader(trainset, batch_size=10000, shuffle=False)

imgs, labels = next(iter(testloader))
# Out:
# Downloading http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz
# Failed to download (trying next):
# HTTP Error 403: Forbidden
#
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/train-images-idx3-ubyte.gz
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/train-images-idx3-ubyte.gz to ./data/MNIST/raw/train-images-idx3-ubyte.gz
# 100%|██████████| 9912422/9912422 [00:01<00:00, 5605665.25it/s]
# Extracting ./data/MNIST/raw/train-images-idx3-ubyte.gz to ./data/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz
# Failed to download (trying next):
# HTTP Error 403: Forbidden
#
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/train-labels-idx1-ubyte.gz
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/train-labels-idx1-ubyte.gz to ./data/MNIST/raw/train-labels-idx1-ubyte.gz
# 100%|██████████| 28881/28881 [00:00<00:00, 1175287.37it/s]
# Extracting ./data/MNIST/raw/train-labels-idx1-ubyte.gz to ./data/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz
# Failed to download (trying next):
# HTTP Error 403: Forbidden
#
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/t10k-images-idx3-ubyte.gz
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/t10k-images-idx3-ubyte.gz to ./data/MNIST/raw/t10k-images-idx3-ubyte.gz
# 100%|██████████| 1648877/1648877 [00:00<00:00, 2356924.78it/s]
# Extracting ./data/MNIST/raw/t10k-images-idx3-ubyte.gz to ./data/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz
# Failed to download (trying next):
# HTTP Error 403: Forbidden
#
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/t10k-labels-idx1-ubyte.gz
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/t10k-labels-idx1-ubyte.gz to ./data/MNIST/raw/t10k-labels-idx1-ubyte.gz
# 100%|██████████| 4542/4542 [00:00<00:00, 3562178.15it/s]
# Extracting ./data/MNIST/raw/t10k-labels-idx1-ubyte.gz to ./data/MNIST/raw

# %% [markdown]
# The `main` function, goes through each instance, initializes the network, adds counter example constraints and calls `net.solve()`

# %%
def main(output_path):
    res = [[-1.]*10 for i in range(START, END)]

    for i in tqdm(range(START, END)):
        data_point = imgs[i].reshape((784)).numpy()
        label = labels[i].item()

        for other_label in range(10):
            if other_label == int(label):
                continue
            net = init_network(data_point, EPSILON)
            net = add_counter_example_constraint(net, label, other_label)
            exit_code, vals, stats = net.solve(options=M_OPTIONS)
            running_time = stats.getTotalTimeInMicro()
            if exit_code=="sat":
                res[i-START][other_label] = "SAT:{}".format(running_time/10**6)
            elif exit_code=="unsat":
                res[i-START][other_label] = "UNS:{}".format(running_time/10**6)
            else:
                res[i-START][other_label] = exit_code

    res = pandas.DataFrame(res)
    res.to_csv(output_path)

# %%
main("./marabou_result.csv")
# Out:
#   0%|          | 0/20 [00:00<?, ?it/s]
# sat
# input 0 = 0.2
# input 1 = 0.2
# input 2 = 0.2
# input 3 = 0.2
# input 4 = 0.2
# input 5 = 0.2
# input 6 = 0.2
# input 7 = 0.0
# input 8 = 0.2
# input 9 = 0.2
# input 10 = 0.2
# input 11 = 0.2
# input 12 = 0.0
# input 13 = 0.2
# input 14 = 0.2
# input 15 = 0.2
# input 16 = 0.2
# input 17 = 0.2
# input 18 = 0.2
# input 19 = 0.2
# input 20 = 0.2
# input 21 = 0.2
# input 22 = 0.2
# input 23 = 0.2
# input 24 = 0.2
# input 25 = 0.2
# input 26 = 0.2
# input 27 = 0.2
# input 28 = 0.2
# input 29 = 0.2
# input 30 = 0.2
# input 31 = 0.2
# input 32 = 0.0
# input 33 = 0.0
# input 34 = 0.0
# input 35 = 0.2
# input 36 = 0.2
# input 37 = 0.2
# input 38 = 0.2
# input 39 = 0.2
# input 40 = 0.2
# input 41 = 0.2
# input 42 = 0.2
# input 43 = 0.2
# input 44 = 0.2
# input 45 = 0.2
# input 46 = 0.2
# input 47 = 0.0
# input 48 = 0.2
# input 49 = 0.2
# input 50 = 0.2
# input 51 = 0.2
# input 52 = 0.2
# input 53 = 0.0
# input 54 = 0.2
# input 55 = 0.2
# input 56 = 0.2
# input 57 = 0.0
# input 58 = 0.2
# input 59 = 0.2
# input 60 = 0.2
# input 61 = 0.2
# input 62 = 0.2
# input 63 = 0.2
# input 64 = 0.2
# input 65 = 0.2
# input 66 = 0.2
# input 67 = 0.2
# input 68 = 0.2
# input 69 = 0.2
# input 70 = 0.2
# input 71 = 0.2
# input 72 = 0.2
# input 73 = 0.2
# input 74 = 0.2
# input 75 = 0.2
# input 76 = 0.2
# input 77 = 0.2
# input 78 = 0.2
# input 79 = 0.2
# input 80 = 0.2
# input 81 = 0.2
# input 82 = 0.2
# input 83 = 0.2
# input 84 = 0.2
# input 85 = 0.2
# input 86 = 0.2
# input 87 = 0.2
# input 88 = 0.2
# input 89 = 0.2
# input 90 = 0.2
# input 91 = 0.0
# input 92 = 0.2
# input 93 = 0.2
# input 94 = 0.2
# input 95 = 0.2
# input 96 = 0.2
# input 97 = 0.2
# input 98 = 0.2
# input 99 = 0.14291855403968995
# input 100 = 0.2
# input 101 = 0.0
# input 102 = 0.2
# input 103 = 0.2
# input 104 = 0.2
# input 105 = 0.2
# input 106 = 0.2
# input 107 = 0.2
# input 108 = 0.2
# input 109 = 0.2
# input 110 = 0.2
# input 111 = 0.2
# input 112 = 0.2
# input 113 = 0.2
# input 114 = 0.2
# input 115 = 0.2
# input 116 = 0.2
# input 117 = 0.0
# input 118 = 0.2
# input 119 = 0.2
# input 120 = 0.2
# input 121 = 0.0
# input 122 = 0.2
# input 123 = 0.2
# input 124 = 0.2
# input 125 = 0.2
# input 126 = 0.2
# input 127 = 0.2
# input 128 = 0.0
# input 129 = 0.2
# input 130 = 0.2
# input 131 = 0.2
# input 132 = 0.2
# input 133 = 0.2
# input 134 = 0.2
# input 135 = 0.2
# input 136 = 0.2
# input 137 = 0.2
# input 138 = 0.2
# input 139 = 0.2
# input 140 = 0.2
# input 141 = 0.2
# input 142 = 0.2
# input 143 = 0.2
# input 144 = 0.2
# input 145 = 0.2
# input 146 = 0.0
# input 147 = 0.2
# input 148 = 0.2
# input 149 = 0.2
# input 150 = 0.2
# input 151 = 0.2
# input 152 = 0.2
# input 153 = 0.2
# input 154 = 0.2
# input 155 = 0.2
# input 156 = 0.2
# input 157 = 0.2
# input 158 = 0.2
# input 159 = 0.2
# input 160 = 0.2
# input 161 = 0.2
# input 162 = 0.2
# input 163 = 0.2
# input 164 = 0.2
# input 165 = 0.2
# input 166 = 0.2
# input 167 = 0.2
# input 168 = 0.2
# input 169 = 0.0
# input 170 = 0.2
# input 171 = 0.2
# input 172 = 0.2
# input 173 = 0.2
# input 174 = 0.2
# input 175 = 0.2
# input 176 = 0.2
# input 177 = 0.2
# input 178 = 0.2
# input 179 = 0.2
# input 180 = 0.0
# input 181 = 0.2
# input 182 = 0.2
# input 183 = 0.2
# input 184 = 0.2
# input 185 = 0.0
# input 186 = 0.0
# input 187 = 0.2
# input 188 = 0.2
# input 189 = 0.2
# input 190 = 0.0
# input 191 = 0.2
# input 192 = 0.2
# input 193 = 0.2
# input 194 = 0.2
# input 195 = 0.0
# input 196 = 0.2
# input 197 = 0.2
# input 198 = 0.2
# input 199 = 0.2
# input 200 = 0.0
# input 201 = 0.2
# input 202 = 0.5294117748737335
# input 203 = 0.9254902124404907
# input 204 = 0.8235294342041015
# input 205 = 0.39215688705444335
# input 206 = 0.24459060332847826
# input 207 = 0.3411764770746231
# input 208 = 0.0
# input 209 = 0.0
# input 210 = 0.18074962363231187
# input 211 = 0.2
# input 212 = 0.2
# input 213 = 0.0
# input 214 = 0.0
# input 215 = 0.0
# input 216 = 0.0
# input 217 = 0.0
# input 218 = 0.0
# input 219 = 0.0
# input 220 = 0.0
# input 221 = 0.2
# input 222 = 0.2
# input 223 = 0.2
# input 224 = 0.2
# input 225 = 0.2
# input 226 = 0.2
# input 227 = 0.0
# input 228 = 0.0
# input 229 = 0.2
# input 230 = 1.0
# input 231 = 0.7960784316062928
# input 232 = 0.7960784316062928
# input 233 = 0.7960784316062928
# input 234 = 0.7960784316062928
# input 235 = 0.7450980424880982
# input 236 = 0.5764706015586853
# input 237 = 0.5764706015586853
# input 238 = 0.5764706015586853
# input 239 = 0.5764706015586853
# input 240 = 0.5764706015586853
# input 241 = 0.5764706015586853
# input 242 = 0.5764706015586853
# input 243 = 0.5764706015586853
# input 244 = 0.4666666865348816
# input 245 = 0.003921571373939503
# input 246 = 0.0
# input 247 = 0.0
# input 248 = 0.2
# input 249 = 0.2
# input 250 = 0.2
# input 251 = 0.2
# input 252 = 0.2
# input 253 = 0.2
# input 254 = 0.2
# input 255 = 0.2
# input 256 = 0.2
# input 257 = 0.2
# input 258 = 0.46274511218070985
# input 259 = 0.24705882668495177
# input 260 = 0.4823529541492462
# input 261 = 0.24705882668495177
# input 262 = 0.43921570777893065
# input 263 = 0.6901960849761963
# input 264 = 0.7960784316062928
# input 265 = 0.6823529481887818
# input 266 = 0.7960784316062928
# input 267 = 0.7960784316062928
# input 268 = 0.7960784316062928
# input 269 = 0.7803921580314637
# input 270 = 0.6980392217636109
# input 271 = 0.7960784316062928
# input 272 = 0.7960784316062928
# input 273 = 0.3490196347236633
# input 274 = 0.0
# input 275 = 0.0
# input 276 = 0.2
# input 277 = 0.2
# input 278 = 0.2
# input 279 = 0.2
# input 280 = 0.2
# input 281 = 0.2
# input 282 = 0.2
# input 283 = 0.2
# input 284 = 0.2
# input 285 = 0.0
# input 286 = 0.2
# input 287 = 0.2
# input 288 = 0.0
# input 289 = 0.0
# input 290 = 0.2
# input 291 = 0.0839255129384306
# input 292 = 0.4588235437870026
# input 293 = 0.1595848351870969
# input 294 = 0.06274511218070983
# input 295 = 0.46274511218070985
# input 296 = 0.06274511218070983
# input 297 = 0.03137255012989043
# input 298 = 0.0
# input 299 = 0.7254902005195618
# input 300 = 0.7960784316062928
# input 301 = 0.21568627953529357
# input 302 = 0.0
# input 303 = 0.0
# input 304 = 0.2
# input 305 = 0.2
# input 306 = 0.2
# input 307 = 0.2
# input 308 = 0.2
# input 309 = 0.2
# input 310 = 0.2
# input 311 = 0.2
# input 312 = 0.2
# input 313 = 0.2
# input 314 = 0.2
# input 315 = 0.0
# input 316 = 0.2
# input 317 = 0.2
# input 318 = 0.2
# input 319 = 0.2
# input 320 = 0.0
# input 321 = 0.0
# input 322 = 0.0
# input 323 = 0.2
# input 324 = 0.2
# input 325 = 0.0
# input 326 = 0.12549020648002623
# input 327 = 0.7921568632125855
# input 328 = 0.6196078538894654
# input 329 = 0.0
# input 330 = 0.0
# input 331 = 0.0
# input 332 = 0.2
# input 333 = 0.2
# input 334 = 0.2
# input 335 = 0.2
# input 336 = 0.2
# input 337 = 0.2
# input 338 = 0.2
# input 339 = 0.2
# input 340 = 0.2
# input 341 = 0.2
# input 342 = 0.0
# input 343 = 0.0
# input 344 = 0.2
# input 345 = 0.0
# input 346 = 0.12484849190244063
# input 347 = 0.2
# input 348 = 0.17168756953428926
# input 349 = 0.0
# input 350 = 0.2
# input 351 = 0.2
# input 352 = 0.0
# input 353 = 0.28627451211214067
# input 354 = 0.71372549533844
# input 355 = 0.8
# input 356 = 0.12549020648002623
# input 357 = 0.0
# input 358 = 0.0
# input 359 = 0.0
# input 360 = 0.2
# input 361 = 0.2
# input 362 = 0.2
# input 363 = 0.2
# input 364 = 0.2
# input 365 = 0.2
# input 366 = 0.2
# input 367 = 0.2
# input 368 = 0.2
# input 369 = 0.2
# input 370 = 0.0
# input 371 = 0.0
# input 372 = 0.2
# input 373 = 0.2
# input 374 = 0.2
# input 375 = 0.2
# input 376 = 0.0
# input 377 = 0.2
# input 378 = 0.2
# input 379 = 0.05396061300177393
# input 380 = 0.0
# input 381 = 0.7058823823928833
# input 382 = 1.0
# input 383 = 0.7333333373069764
# input 384 = 0.0
# input 385 = 0.0
# input 386 = 0.2
# input 387 = 0.2
# input 388 = 0.2
# input 389 = 0.2
# input 390 = 0.2
# input 391 = 0.2
# input 392 = 0.2
# input 393 = 0.2
# input 394 = 0.2
# input 395 = 0.2
# input 396 = 0.2
# input 397 = 0.2
# input 398 = 0.2
# input 399 = 0.03716823083406013
# input 400 = 0.0
# input 401 = 0.0
# input 402 = 0.0
# input 403 = 0.0
# input 404 = 0.15950643140802717
# input 405 = 0.2
# input 406 = 0.0
# input 407 = 0.0
# input 408 = 0.03137255012989043
# input 409 = 1.0
# input 410 = 0.7960784316062928
# input 411 = 0.04313725531101226
# input 412 = 0.0
# input 413 = 0.0
# input 414 = 0.2
# input 415 = 0.0
# input 416 = 0.2
# input 417 = 0.2
# input 418 = 0.2
# input 419 = 0.2
# input 420 = 0.2
# input 421 = 0.2
# input 422 = 0.2
# input 423 = 0.0
# input 424 = 0.2
# input 425 = 0.2
# input 426 = 0.0
# input 427 = 0.0
# input 428 = 0.0
# input 429 = 0.0
# input 430 = 0.0
# input 431 = 0.2
# input 432 = 0.2
# input 433 = 0.2
# input 434 = 0.2
# input 435 = 0.2
# input 436 = 0.7215686559677124
# input 437 = 1.0
# input 438 = 0.5333333492279053
# input 439 = 0.0
# input 440 = 0.0
# input 441 = 0.0
# input 442 = 0.0
# input 443 = 0.2
# input 444 = 0.2
# input 445 = 0.2
# input 446 = 0.2
# input 447 = 0.2
# input 448 = 0.2
# input 449 = 0.2
# input 450 = 0.2
# input 451 = 0.2
# input 452 = 0.2
# input 453 = 0.0
# input 454 = 0.0
# input 455 = 0.0
# input 456 = 0.2
# input 457 = 0.1686330901146952
# input 458 = 0.2
# input 459 = 0.2
# input 460 = 0.2
# input 461 = 0.2
# input 462 = 0.2
# input 463 = 0.2352941192686558
# input 464 = 1.0
# input 465 = 0.7725490212440491
# input 466 = 0.4274509817361832
# input 467 = 0.0
# input 468 = 0.0
# input 469 = 0.0
# input 470 = 0.2
# input 471 = 0.2
# input 472 = 0.2
# input 473 = 0.2
# input 474 = 0.2
# input 475 = 0.2
# input 476 = 0.2
# input 477 = 0.2
# input 478 = 0.2
# input 479 = 0.2
# input 480 = 0.2
# input 481 = 0.0
# input 482 = 0.0
# input 483 = 0.0
# input 484 = 0.0
# input 485 = 0.0
# input 486 = 0.2
# input 487 = 0.2
# input 488 = 0.2
# input 489 = 0.1005762776350992
# input 490 = 0.0
# input 491 = 0.2941176474094391
# input 492 = 0.7960784316062928
# input 493 = 0.5137255072593689
# input 494 = 0.0
# input 495 = 0.0
# input 496 = 0.0
# input 497 = 0.2
# input 498 = 0.2
# input 499 = 0.2
# input 500 = 0.2
# input 501 = 0.2
# input 502 = 0.2
# input 503 = 0.2
# input 504 = 0.2
# input 505 = 0.2
# input 506 = 0.2
# input 507 = 0.2
# input 508 = 0.2
# input 509 = 0.0
# input 510 = 0.0
# input 511 = 0.0
# input 512 = 0.2
# input 513 = 0.2
# input 514 = 0.2
# input 515 = 0.0
# input 516 = 0.11210017957121075
# input 517 = 0.0
# input 518 = 0.09411765933036803
# input 519 = 0.7843137264251709
# input 520 = 0.7411764740943909
# input 521 = 0.4235294133424759
# input 522 = 0.2
# input 523 = 0.2
# input 524 = 0.0
# input 525 = 0.2
# input 526 = 0.2
# input 527 = 0.2
# input 528 = 0.2
# input 529 = 0.2
# input 530 = 0.2
# input 531 = 0.2
# input 532 = 0.2
# input 533 = 0.2
# input 534 = 0.2
# input 535 = 0.2
# input 536 = 0.2
# input 537 = 0.0
# input 538 = 0.2
# input 539 = 0.2
# input 540 = 0.062321374842067165
# input 541 = 0.0
# input 542 = 0.2
# input 543 = 0.2
# input 544 = 0.2
# input 545 = 0.0
# input 546 = 0.6666666746139527
# input 547 = 1.0
# input 548 = 0.8509804129600524
# input 549 = 0.2
# input 550 = 0.2
# input 551 = 0.2
# input 552 = 0.0
# input 553 = 0.2
# input 554 = 0.2
# input 555 = 0.2
# input 556 = 0.2
# input 557 = 0.2
# input 558 = 0.2
# input 559 = 0.0
# input 560 = 0.2
# input 561 = 0.2
# input 562 = 0.2
# input 563 = 0.2
# input 564 = 0.2
# input 565 = 0.0
# input 566 = 0.2
# input 567 = 0.2
# input 568 = 0.2
# input 569 = 0.2
# input 570 = 0.2
# input 571 = 0.2
# input 572 = 0.2117647061124444
# input 573 = 0.9960784435272216
# input 574 = 1.0
# input 575 = 1.0
# input 576 = 0.33725490868091584
# input 577 = 0.2
# input 578 = 0.2
# input 579 = 0.2
# input 580 = 0.0
# input 581 = 0.2
# input 582 = 0.2
# input 583 = 0.2
# input 584 = 0.2
# input 585 = 0.2
# input 586 = 0.2
# input 587 = 0.2
# input 588 = 0.2
# input 589 = 0.2
# input 590 = 0.2
# input 591 = 0.2
# input 592 = 0.2
# input 593 = 0.2
# input 594 = 0.2
# input 595 = 0.2
# input 596 = 0.2
# input 597 = 0.2
# input 598 = 0.0
# input 599 = 0.2
# input 600 = 0.34901961386203767
# input 601 = 1.0
# input 602 = 1.0
# input 603 = 0.5019607961177825
# input 604 = 0.2
# input 605 = 0.2
# input 606 = 0.2
# input 607 = 0.2
# input 608 = 0.2
# input 609 = 0.2
# input 610 = 0.0
# input 611 = 0.2
# input 612 = 0.2
# input 613 = 0.2
# input 614 = 0.2
# input 615 = 0.2
# input 616 = 0.2
# input 617 = 0.2
# input 618 = 0.2
# input 619 = 0.2
# input 620 = 0.2
# input 621 = 0.2
# input 622 = 0.004053936999897679
# input 623 = 0.2
# input 624 = 0.2
# input 625 = 0.2
# input 626 = 0.2
# input 627 = 0.32156862765550615
# input 628 = 1.0
# input 629 = 1.0
# input 630 = 0.650980395078659
# input 631 = 0.20392156885936857
# input 632 = 0.0
# input 633 = 0.2
# input 634 = 0.2
# input 635 = 0.2
# input 636 = 0.2
# input 637 = 0.2
# input 638 = 0.2
# input 639 = 0.2
# input 640 = 0.2
# input 641 = 0.2
# input 642 = 0.2
# input 643 = 0.2
# input 644 = 0.2
# input 645 = 0.2
# input 646 = 0.2
# input 647 = 0.2
# input 648 = 0.0
# input 649 = 0.0
# input 650 = 0.0
# input 651 = 0.0
# input 652 = 0.0
# input 653 = 0.0
# input 654 = 0.0
# input 655 = 0.3215686559677124
# input 656 = 0.7960784316062928
# input 657 = 0.7960784316062928
# input 658 = 0.003921571373939503
# input 659 = 0.0
# input 660 = 0.0
# input 661 = 0.2
# input 662 = 0.2
# input 663 = 0.2
# input 664 = 0.2
# input 665 = 0.2
# input 666 = 0.2
# input 667 = 0.2
# input 668 = 0.2
# input 669 = 0.2
# input 670 = 0.2
# input 671 = 0.2
# input 672 = 0.2
# input 673 = 0.2
# input 674 = 0.0
# input 675 = 0.2
# input 676 = 0.0
# input 677 = 0.0
# input 678 = 0.0
# input 679 = 0.0
# input 680 = 0.0
# input 681 = 0.0
# input 682 = 0.03921568691730498
# input 683 = 0.7490196108818055
# input 684 = 0.7960784316062928
# input 685 = 0.7960784316062928
# input 686 = 0.003921571373939503
# input 687 = 0.0
# input 688 = 0.2
# input 689 = 0.2
# input 690 = 0.2
# input 691 = 0.2
# input 692 = 0.2
# input 693 = 0.2
# input 694 = 0.2
# input 695 = 0.2
# input 696 = 0.2
# input 697 = 0.2
# input 698 = 0.2
# input 699 = 0.0
# input 700 = 0.0
# input 701 = 0.2
# input 702 = 0.2
# input 703 = 0.2
# input 704 = 0.2
# input 705 = 0.0
# input 706 = 0.0
# input 707 = 0.0
# input 708 = 0.0
# input 709 = 0.0
# input 710 = 0.2745098054409027
# input 711 = 0.7960784316062928
# input 712 = 0.7960784316062928
# input 713 = 0.6588235378265381
# input 714 = 0.3568627506494522
# input 715 = 0.0
# input 716 = 0.2
# input 717 = 0.2
# input 718 = 0.2
# input 719 = 0.2
# input 720 = 0.2
# input 721 = 0.2
# input 722 = 0.2
# input 723 = 0.2
# input 724 = 0.2
# input 725 = 0.2
# input 726 = 0.2
# input 727 = 0.2
# input 728 = 0.2
# input 729 = 0.2
# input 730 = 0.2
# input 731 = 0.2
# input 732 = 0.0
# input 733 = 0.2
# input 734 = 0.0
# input 735 = 0.0
# input 736 = 0.0
# input 737 = 0.0
# input 738 = 0.6745098054409027
# input 739 = 1.0
# input 740 = 1.0
# input 741 = 0.27058823853731157
# input 742 = 0.2
# input 743 = 0.0
# input 744 = 0.0
# input 745 = 0.2
# input 746 = 0.2
# input 747 = 0.2
# input 748 = 0.2
# input 749 = 0.2
# input 750 = 0.2
# input 751 = 0.2
# input 752 = 0.2
# input 753 = 0.2
# input 754 = 0.2
# input 755 = 0.2
# input 756 = 0.2
# input 757 = 0.2
# input 758 = 0.2
# input 759 = 0.0
# input 760 = 0.2
# input 761 = 0.2
# input 762 = 0.2
# input 763 = 0.2
# input 764 = 0.2
# input 765 = 0.2
# input 766 = 0.2
# input 767 = 0.2
# input 768 = 0.2
# input 769 = 0.2
# input 770 = 0.2
# input 771 = 0.2
# input 772 = 0.2
# input 773 = 0.2
# input 774 = 0.2
# input 775 = 0.2
# input 776 = 0.2
# input 777 = 0.2
# input 778 = 0.0
# input 779 = 0.2
# input 780 = 0.2
# input 781 = 0.2
# input 782 = 0.2
# input 783 = 0.2
# output 0 = -1.8544543089247416
# output 1 = -2.4124204100699043
# output 2 = -0.34206787721777154
# output 3 = -1.355088377067347
# output 4 = -2.786898036216545
# output 5 = -1.7948375569818968
# output 6 = -2.542071741265827
# output 7 = -1.8545543089247432
# output 8 = -1.0236910772692922
# output 9 = -1.6364408887250512
# sat
# input 0 = 0.2
# input 1 = 0.0
# input 2 = 0.2
# input 3 = 0.0
# input 4 = 0.2
# input 5 = 0.0
# input 6 = 0.2
# input 7 = 0.2
# input 8 = 0.0
# input 9 = 0.2
# input 10 = 0.2
# input 11 = 0.0
# input 12 = 0.2
# input 13 = 0.2
# input 14 = 0.2
# input 15 = 0.2
# input 16 = 0.2
# input 17 = 0.2
# input 18 = 0.2
# input 19 = 0.0
# input 20 = 0.2
# input 21 = 0.2
# input 22 = 0.0
# input 23 = 0.2
# input 24 = 0.2
# input 25 = 0.2
# input 26 = 0.0
# input 27 = 0.2
# input 28 = 0.2
# input 29 = 0.0
# input 30 = 0.0
# input 31 = 0.0
# input 32 = 0.0
# input 33 = 0.0
# input 34 = 0.0
# input 35 = 0.2
# input 36 = 0.2
# input 37 = 0.0
# input 38 = 0.2
# input 39 = 0.2
# input 40 = 0.0
# input 41 = 0.2
# input 42 = 0.2
# input 43 = 0.0
# input 44 = 0.2
# input 45 = 0.0
# input 46 = 0.2
# input 47 = 0.0
# input 48 = 0.2
# input 49 = 0.2
# input 50 = 0.2
# input 51 = 0.0
# input 52 = 0.2
# input 53 = 0.2
# input 54 = 0.2
# input 55 = 0.0
# input 56 = 0.0
# input 57 = 0.0
# input 58 = 0.0
# input 59 = 0.2
# input 60 = 0.0
# input 61 = 0.2
# input 62 = 0.2
# input 63 = 0.2
# input 64 = 0.0
# input 65 = 0.2
# input 66 = 0.2
# input 67 = 0.2
# input 68 = 0.2
# input 69 = 0.0
# input 70 = 0.2
# input 71 = 0.2
# input 72 = 0.2
# input 73 = 0.2
# input 74 = 0.2
# input 75 = 0.2
# input 76 = 0.2
# input 77 = 0.0
# input 78 = 0.2
# input 79 = 0.0
# input 80 = 0.0
# input 81 = 0.2
# input 82 = 0.2
# input 83 = 0.2
# input 84 = 0.2
# input 85 = 0.0
# input 86 = 0.0
# input 87 = 0.2
# input 88 = 0.0
# input 89 = 0.2
# input 90 = 0.0
# input 91 = 0.0
# input 92 = 0.2
# input 93 = 0.2
# input 94 = 0.2
# input 95 = 0.2
# input 96 = 0.2
# input 97 = 0.2
# input 98 = 0.2
# input 99 = 0.2
# input 100 = 0.2
# input 101 = 0.004077834482679161
# input 102 = 0.2
# input 103 = 0.2
# input 104 = 0.2
# input 105 = 0.2
# input 106 = 0.2
# input 107 = 0.0
# input 108 = 0.2
# input 109 = 0.2
# input 110 = 0.2
# input 111 = 0.0
# input 112 = 0.2
# input 113 = 0.2
# input 114 = 0.2
# input 115 = 0.2
# input 116 = 0.0
# input 117 = 0.2
# input 118 = 0.2
# input 119 = 0.2
# input 120 = 0.0
# input 121 = 0.0
# input 122 = 0.2
# input 123 = 0.0
# input 124 = 0.2
# input 125 = 0.0
# input 126 = 0.2
# input 127 = 0.0
# input 128 = 0.0
# input 129 = 0.2
# input 130 = 0.0
# input 131 = 0.2
# input 132 = 0.2
# input 133 = 0.2
# input 134 = 0.2
# input 135 = 0.0
# input 136 = 0.2
# input 137 = 0.0
# input 138 = 0.0
# input 139 = 0.2
# input 140 = 0.2
# input 141 = 0.2
# input 142 = 0.2
# input 143 = 0.2
# input 144 = 0.2
# input 145 = 0.2
# input 146 = 0.0
# input 147 = 0.2
# input 148 = 0.0
# input 149 = 0.2
# input 150 = 0.2
# input 151 = 0.2
# input 152 = 0.2
# input 153 = 0.2
# input 154 = 0.2
# input 155 = 0.2
# input 156 = 0.2
# input 157 = 0.2
# input 158 = 0.2
# input 159 = 0.2
# input 160 = 0.2
# input 161 = 0.2
# input 162 = 0.0
# input 163 = 0.2
# input 164 = 0.2
# input 165 = 0.2
# input 166 = 0.2
# input 167 = 0.2
# input 168 = 0.2
# input 169 = 0.2
# input 170 = 0.2
# input 171 = 0.2
# input 172 = 0.2
# input 173 = 0.2
# input 174 = 0.0
# input 175 = 0.0
# input 176 = 0.2
# input 177 = 0.2
# input 178 = 0.2
# input 179 = 0.2
# input 180 = 0.2
# input 181 = 0.2
# input 182 = 0.2
# input 183 = 0.2
# input 184 = 0.2
# input 185 = 0.0
# input 186 = 0.0
# input 187 = 0.2
# input 188 = 0.2
# input 189 = 0.0
# input 190 = 0.0
# input 191 = 0.0
# input 192 = 0.2
# input 193 = 0.2
# input 194 = 0.0
# input 195 = 0.2
# input 196 = 0.2
# input 197 = 0.2
# input 198 = 0.2
# input 199 = 0.2
# input 200 = 0.0
# input 201 = 0.0
# input 202 = 0.1294117748737335
# input 203 = 0.9254902124404907
# input 204 = 0.8235294342041015
# input 205 = 0.49527447163665733
# input 206 = 0.035294118523597706
# input 207 = 0.0
# input 208 = 0.0
# input 209 = 0.0
# input 210 = 0.2
# input 211 = 0.2
# input 212 = 0.08926925477521458
# input 213 = 0.0
# input 214 = 0.0
# input 215 = 0.17738544903726575
# input 216 = 0.0
# input 217 = 0.0
# input 218 = 0.0
# input 219 = 0.0
# input 220 = 0.0
# input 221 = 0.0
# input 222 = 0.0
# input 223 = 0.0
# input 224 = 0.2
# input 225 = 0.2
# input 226 = 0.2
# input 227 = 0.0
# input 228 = 0.0
# input 229 = 0.0
# input 230 = 1.0
# input 231 = 0.7960784316062928
# input 232 = 0.7960784316062928
# input 233 = 0.7960784316062928
# input 234 = 0.7960784316062928
# input 235 = 0.7450980424880982
# input 236 = 0.5764706015586853
# input 237 = 0.5764706015586853
# input 238 = 0.5764706015586853
# input 239 = 0.5764706015586853
# input 240 = 0.5764706015586853
# input 241 = 0.5764706015586853
# input 242 = 0.5764706015586853
# input 243 = 0.5764706015586853
# input 244 = 0.4666666865348816
# input 245 = 0.003921571373939503
# input 246 = 0.0
# input 247 = 0.0
# input 248 = 0.0
# input 249 = 0.2
# input 250 = 0.2
# input 251 = 0.0
# input 252 = 0.0
# input 253 = 0.2
# input 254 = 0.0
# input 255 = 0.2
# input 256 = 0.2
# input 257 = 0.2
# input 258 = 0.46274511218070985
# input 259 = 0.24705882668495177
# input 260 = 0.0823529541492462
# input 261 = 0.24705882668495177
# input 262 = 0.43921570777893065
# input 263 = 0.6901960849761963
# input 264 = 0.7960784316062928
# input 265 = 0.6823529481887818
# input 266 = 0.7960784316062928
# input 267 = 0.7960784316062928
# input 268 = 0.7960784316062928
# input 269 = 0.7803921580314637
# input 270 = 0.6980392217636109
# input 271 = 0.7960784316062928
# input 272 = 0.7960784316062928
# input 273 = 0.3490196347236633
# input 274 = 0.0
# input 275 = 0.0
# input 276 = 0.2
# input 277 = 0.0
# input 278 = 0.2
# input 279 = 0.2
# input 280 = 0.2
# input 281 = 0.2
# input 282 = 0.0
# input 283 = 0.0
# input 284 = 0.2
# input 285 = 0.2
# input 286 = 0.0
# input 287 = 0.0
# input 288 = 0.0
# input 289 = 0.0
# input 290 = 0.0
# input 291 = 0.0
# input 292 = 0.05882354378700255
# input 293 = 0.25490196123719217
# input 294 = 0.06274511218070983
# input 295 = 0.46274511218070985
# input 296 = 0.06274511218070983
# input 297 = 0.03137255012989043
# input 298 = 0.0
# input 299 = 0.7254902005195618
# input 300 = 0.7960784316062928
# input 301 = 0.21568627953529357
# input 302 = 0.0
# input 303 = 0.0
# input 304 = 0.2
# input 305 = 0.2
# input 306 = 0.0
# input 307 = 0.0
# input 308 = 0.0
# input 309 = 0.2
# input 310 = 0.2
# input 311 = 0.0
# input 312 = 0.0
# input 313 = 0.2
# input 314 = 0.2
# input 315 = 0.0
# input 316 = 0.2
# input 317 = 0.2
# input 318 = 0.2
# input 319 = 0.2
# input 320 = 0.2
# input 321 = 0.2
# input 322 = 0.1367382375845052
# input 323 = 0.2
# input 324 = 0.0
# input 325 = 0.0
# input 326 = 0.12549020648002623
# input 327 = 0.7921568632125855
# input 328 = 0.6196078538894654
# input 329 = 0.0
# input 330 = 0.0
# input 331 = 0.0
# input 332 = 0.2
# input 333 = 0.2
# input 334 = 0.0
# input 335 = 0.2
# input 336 = 0.2
# input 337 = 0.2
# input 338 = 0.0
# input 339 = 0.2
# input 340 = 0.2
# input 341 = 0.2
# input 342 = 0.0
# input 343 = 0.0
# input 344 = 0.0
# input 345 = 0.0
# input 346 = 0.0
# input 347 = 0.14723579867369763
# input 348 = 0.2
# input 349 = 0.2
# input 350 = 0.2
# input 351 = 0.2
# input 352 = 0.0
# input 353 = 0.0
# input 354 = 0.71372549533844
# input 355 = 0.8
# input 356 = 0.12549020648002623
# input 357 = 0.0
# input 358 = 0.0
# input 359 = 0.0
# input 360 = 0.2
# input 361 = 0.2
# input 362 = 0.0
# input 363 = 0.2
# input 364 = 0.0
# input 365 = 0.2
# input 366 = 0.0
# input 367 = 0.2
# input 368 = 0.2
# input 369 = 0.2
# input 370 = 0.0
# input 371 = 0.0
# input 372 = 0.0
# input 373 = 0.2
# input 374 = 0.2
# input 375 = 0.2
# input 376 = 0.2
# input 377 = 0.2
# input 378 = 0.2
# input 379 = 0.18310465286719435
# input 380 = 0.0
# input 381 = 0.3058823823928833
# input 382 = 0.7960784316062928
# input 383 = 0.7333333373069764
# input 384 = 0.0
# input 385 = 0.0
# input 386 = 0.2
# input 387 = 0.2
# input 388 = 0.2
# input 389 = 0.0
# input 390 = 0.0
# input 391 = 0.2
# input 392 = 0.0
# input 393 = 0.0
# input 394 = 0.2
# input 395 = 0.2
# input 396 = 0.2
# input 397 = 0.2
# input 398 = 0.0
# input 399 = 0.0
# input 400 = 0.0
# input 401 = 0.0
# input 402 = 0.0
# input 403 = 0.0
# input 404 = 0.07483136627910811
# input 405 = 0.0
# input 406 = 0.0
# input 407 = 0.0
# input 408 = 0.03137255012989043
# input 409 = 0.7764705896377564
# input 410 = 0.7960784316062928
# input 411 = 0.04313725531101226
# input 412 = 0.0
# input 413 = 0.0
# input 414 = 0.2
# input 415 = 0.0
# input 416 = 0.2
# input 417 = 0.0
# input 418 = 0.2
# input 419 = 0.0
# input 420 = 0.2
# input 421 = 0.0
# input 422 = 0.2
# input 423 = 0.0
# input 424 = 0.2
# input 425 = 0.2
# input 426 = 0.0
# input 427 = 0.0
# input 428 = 0.0
# input 429 = 0.0
# input 430 = 0.0
# input 431 = 0.0
# input 432 = 0.0
# input 433 = 0.0
# input 434 = 0.0
# input 435 = 0.0
# input 436 = 0.3215686559677124
# input 437 = 0.7960784316062928
# input 438 = 0.5333333492279053
# input 439 = 0.0
# input 440 = 0.0
# input 441 = 0.0
# input 442 = 0.0
# input 443 = 0.2
# input 444 = 0.0
# input 445 = 0.0
# input 446 = 0.0
# input 447 = 0.2
# input 448 = 0.2
# input 449 = 0.0
# input 450 = 0.2
# input 451 = 0.2
# input 452 = 0.2
# input 453 = 0.0
# input 454 = 0.0
# input 455 = 0.0
# input 456 = 0.0
# input 457 = 0.0
# input 458 = 0.0
# input 459 = 0.0
# input 460 = 0.2
# input 461 = 0.2
# input 462 = 0.0
# input 463 = 0.0
# input 464 = 0.6039215803146363
# input 465 = 0.7725490212440491
# input 466 = 0.027450981736183155
# input 467 = 0.0
# input 468 = 0.0
# input 469 = 0.2
# input 470 = 0.2
# input 471 = 0.2
# input 472 = 0.0
# input 473 = 0.0
# input 474 = 0.2
# input 475 = 0.0
# input 476 = 0.2
# input 477 = 0.0
# input 478 = 0.2
# input 479 = 0.2
# input 480 = 0.2
# input 481 = 0.0
# input 482 = 0.0
# input 483 = 0.0
# input 484 = 0.05011077478600563
# input 485 = 0.0
# input 486 = 0.0
# input 487 = 0.0
# input 488 = 0.09248705681551977
# input 489 = 0.0
# input 490 = 0.0
# input 491 = 0.2941176474094391
# input 492 = 0.7960784316062928
# input 493 = 0.5137255072593689
# input 494 = 0.0
# input 495 = 0.0
# input 496 = 0.2
# input 497 = 0.2
# input 498 = 0.2
# input 499 = 0.2
# input 500 = 0.2
# input 501 = 0.0
# input 502 = 0.0
# input 503 = 0.0
# input 504 = 0.0
# input 505 = 0.2
# input 506 = 0.2
# input 507 = 0.2
# input 508 = 0.2
# input 509 = 0.2
# input 510 = 0.2
# input 511 = 0.2
# input 512 = 0.0
# input 513 = 0.0
# input 514 = 0.0
# input 515 = 0.2
# input 516 = 0.2
# input 517 = 0.0
# input 518 = 0.09411765933036803
# input 519 = 0.7843137264251709
# input 520 = 0.7411764740943909
# input 521 = 0.02352941334247588
# input 522 = 0.2
# input 523 = 0.2
# input 524 = 0.2
# input 525 = 0.2
# input 526 = 0.2
# input 527 = 0.2
# input 528 = 0.0
# input 529 = 0.2
# input 530 = 0.2
# input 531 = 0.0
# input 532 = 0.2
# input 533 = 0.2
# input 534 = 0.0
# input 535 = 0.2
# input 536 = 0.2
# input 537 = 0.2
# input 538 = 0.2
# input 539 = 0.2
# input 540 = 0.19404083297562924
# input 541 = 0.2
# input 542 = 0.2
# input 543 = 0.2
# input 544 = 0.02890159472123856
# input 545 = 0.0
# input 546 = 0.6666666746139527
# input 547 = 0.7960784316062928
# input 548 = 0.8509804129600524
# input 549 = 0.2
# input 550 = 0.2
# input 551 = 0.2
# input 552 = 0.2
# input 553 = 0.2
# input 554 = 0.2
# input 555 = 0.0
# input 556 = 0.0
# input 557 = 0.0
# input 558 = 0.2
# input 559 = 0.2
# input 560 = 0.0
# input 561 = 0.2
# input 562 = 0.0
# input 563 = 0.0
# input 564 = 0.2
# input 565 = 0.2
# input 566 = 0.2
# input 567 = 0.2
# input 568 = 0.2
# input 569 = 0.2
# input 570 = 0.2
# input 571 = 0.2
# input 572 = 0.2117647061124444
# input 573 = 0.9960784435272216
# input 574 = 1.0
# input 575 = 1.0
# input 576 = 0.33725490868091584
# input 577 = 0.2
# input 578 = 0.2
# input 579 = 0.2
# input 580 = 0.2
# input 581 = 0.2
# input 582 = 0.2
# input 583 = 0.0
# input 584 = 0.2
# input 585 = 0.2
# input 586 = 0.0
# input 587 = 0.2
# input 588 = 0.0
# input 589 = 0.2
# input 590 = 0.0
# input 591 = 0.0
# input 592 = 0.2
# input 593 = 0.2
# input 594 = 0.2
# input 595 = 0.2
# input 596 = 0.2
# input 597 = 0.2
# input 598 = 0.2
# input 599 = 0.13201674062856128
# input 600 = 0.34901961386203767
# input 601 = 0.7960784316062928
# input 602 = 1.0
# input 603 = 0.5019607961177825
# input 604 = 0.2
# input 605 = 0.2
# input 606 = 0.2
# input 607 = 0.2
# input 608 = 0.2
# input 609 = 0.2
# input 610 = 0.0
# input 611 = 0.0
# input 612 = 0.0
# input 613 = 0.2
# input 614 = 0.0
# input 615 = 0.2
# input 616 = 0.2
# input 617 = 0.0
# input 618 = 0.2
# input 619 = 0.2
# input 620 = 0.0
# input 621 = 0.2
# input 622 = 0.2
# input 623 = 0.2
# input 624 = 0.2
# input 625 = 0.2
# input 626 = 0.2
# input 627 = 0.32156862765550615
# input 628 = 1.0
# input 629 = 1.0
# input 630 = 0.650980395078659
# input 631 = 0.0
# input 632 = 0.0
# input 633 = 0.0
# input 634 = 0.2
# input 635 = 0.2
# input 636 = 0.2
# input 637 = 0.2
# input 638 = 0.0
# input 639 = 0.2
# input 640 = 0.2
# input 641 = 0.0
# input 642 = 0.0
# input 643 = 0.2
# input 644 = 0.0
# input 645 = 0.2
# input 646 = 0.2
# input 647 = 0.0
# input 648 = 0.0
# input 649 = 0.0
# input 650 = 0.0
# input 651 = 0.0
# input 652 = 0.0
# input 653 = 0.0
# input 654 = 0.0
# input 655 = 0.3215686559677124
# input 656 = 0.7960784316062928
# input 657 = 0.7960784316062928
# input 658 = 0.003921571373939503
# input 659 = 0.0
# input 660 = 0.0
# input 661 = 0.0
# input 662 = 0.0
# input 663 = 0.0
# input 664 = 0.2
# input 665 = 0.2
# input 666 = 0.2
# input 667 = 0.2
# input 668 = 0.0
# input 669 = 0.2
# input 670 = 0.0
# input 671 = 0.2
# input 672 = 0.2
# input 673 = 0.2
# input 674 = 0.0
# input 675 = 0.0
# input 676 = 0.0
# input 677 = 0.0
# input 678 = 0.0
# input 679 = 0.0
# input 680 = 0.0
# input 681 = 0.0
# input 682 = 0.03921568691730498
# input 683 = 0.7490196108818055
# input 684 = 0.7960784316062928
# input 685 = 0.7960784316062928
# input 686 = 0.003921571373939503
# input 687 = 0.0
# input 688 = 0.0
# input 689 = 0.0
# input 690 = 0.0
# input 691 = 0.2
# input 692 = 0.2
# input 693 = 0.2
# input 694 = 0.0
# input 695 = 0.2
# input 696 = 0.2
# input 697 = 0.0
# input 698 = 0.0
# input 699 = 0.0
# input 700 = 0.0
# input 701 = 0.0
# input 702 = 0.2
# input 703 = 0.2
# input 704 = 0.2
# input 705 = 0.0
# input 706 = 0.0
# input 707 = 0.0
# input 708 = 0.0
# input 709 = 0.0
# input 710 = 0.2745098054409027
# input 711 = 0.7960784316062928
# input 712 = 0.7960784316062928
# input 713 = 1.0
# input 714 = 0.0
# input 715 = 0.0
# input 716 = 0.0
# input 717 = 0.0
# input 718 = 0.0
# input 719 = 0.0
# input 720 = 0.2
# input 721 = 0.0
# input 722 = 0.2
# input 723 = 0.0
# input 724 = 0.2
# input 725 = 0.0
# input 726 = 0.0
# input 727 = 0.0
# input 728 = 0.2
# input 729 = 0.0
# input 730 = 0.0
# input 731 = 0.2
# input 732 = 0.0
# input 733 = 0.0
# input 734 = 0.0
# input 735 = 0.2
# input 736 = 0.2
# input 737 = 0.2
# input 738 = 0.6745098054409027
# input 739 = 1.0
# input 740 = 1.0
# input 741 = 0.0
# input 742 = 0.2
# input 743 = 0.0
# input 744 = 0.0
# input 745 = 0.2
# input 746 = 0.0
# input 747 = 0.2
# input 748 = 0.2
# input 749 = 0.2
# input 750 = 0.2
# input 751 = 0.2
# input 752 = 0.2
# input 753 = 0.2
# input 754 = 0.0
# input 755 = 0.2
# input 756 = 0.2
# input 757 = 0.2
# input 758 = 0.2
# input 759 = 0.0
# input 760 = 0.0
# input 761 = 0.2
# input 762 = 0.0
# input 763 = 0.2
# input 764 = 0.0
# input 765 = 0.2
# input 766 = 0.0
# input 767 = 0.2
# input 768 = 0.2
# input 769 = 0.2
# input 770 = 0.0
# input 771 = 0.2
# input 772 = 0.2
# input 773 = 0.2
# input 774 = 0.2
# input 775 = 0.2
# input 776 = 0.0
# input 777 = 0.2
# input 778 = 0.0
# input 779 = 0.2
# input 780 = 0.2
# input 781 = 0.2
# input 782 = 0.2
# input 783 = 0.0
# output 0 = -3.392941988593423
# output 1 = -1.1333142635211597
# output 2 = 0.5789873503397086
# output 3 = 0.6269611426213266
# output 4 = -3.787353113524228
# output 5 = -1.0559797814859122
# output 6 = -3.1980290057784995
# output 7 = -1.133414263521161
# output 8 = -1.09084287672169
# output 9 = -2.652423261224463
# sat
# input 0 = 0.2
# input 1 = 0.2
# input 2 = 0.2
# input 3 = 0.0
# input 4 = 0.2
# input 5 = 0.2
# input 6 = 0.2
# input 7 = 0.2
# input 8 = 0.0
# input 9 = 0.2
# input 10 = 0.0
# input 11 = 0.0
# input 12 = 0.2
# input 13 = 0.0
# input 14 = 0.0
# input 15 = 0.2
# input 16 = 0.0
# input 17 = 0.2
# input 18 = 0.2
# input 19 = 0.0
# input 20 = 0.0
# input 21 = 0.2
# input 22 = 0.2
# input 23 = 0.2
# input 24 = 0.2
# input 25 = 0.0
# input 26 = 0.0
# input 27 = 0.0
# input 28 = 0.0
# input 29 = 0.2
# input 30 = 0.0
# input 31 = 0.0
# input 32 = 0.2
# input 33 = 0.0
# input 34 = 0.0
# input 35 = 0.2
# input 36 = 0.2
# input 37 = 0.0
# input 38 = 0.2
# input 39 = 0.0
# input 40 = 0.0
# input 41 = 0.0
# input 42 = 0.2
# input 43 = 0.0
# input 44 = 0.2
# input 45 = 0.0
# input 46 = 0.2
# input 47 = 0.0
# input 48 = 0.0
# input 49 = 0.2
# input 50 = 0.2
# input 51 = 0.0
# input 52 = 0.0
# input 53 = 0.0
# input 54 = 0.2
# input 55 = 0.0
# input 56 = 0.0
# input 57 = 0.0
# input 58 = 0.0
# input 59 = 0.2
# input 60 = 0.0
# input 61 = 0.0
# input 62 = 0.0
# input 63 = 0.2
# input 64 = 0.2
# input 65 = 0.0
# input 66 = 0.2
# input 67 = 0.0
# input 68 = 0.0
# input 69 = 0.0
# input 70 = 0.0
# input 71 = 0.2
# input 72 = 0.0
# input 73 = 0.0
# input 74 = 0.2
# input 75 = 0.0
# input 76 = 0.0
# input 77 = 0.2
# input 78 = 0.0
# input 79 = 0.2
# input 80 = 0.0
# input 81 = 0.0
# input 82 = 0.2
# input 83 = 0.2
# input 84 = 0.0
# input 85 = 0.0
# input 86 = 0.0
# input 87 = 0.0
# input 88 = 0.0
# input 89 = 0.2
# input 90 = 0.2
# input 91 = 0.0
# input 92 = 0.2
# input 93 = 0.2
# input 94 = 0.2
# input 95 = 0.0
# input 96 = 0.2
# input 97 = 0.0
# input 98 = 0.0
# input 99 = 0.0
# input 100 = 0.2
# input 101 = 0.0
# input 102 = 0.2
# input 103 = 0.2
# input 104 = 0.2
# input 105 = 0.2
# input 106 = 0.2
# input 107 = 0.2
# input 108 = 0.2
# input 109 = 0.0
# input 110 = 0.0
# input 111 = 0.0
# input 112 = 0.2
# input 113 = 0.2
# input 114 = 0.2
# input 115 = 0.2
# input 116 = 0.0
# input 117 = 0.0
# input 118 = 0.2
# input 119 = 0.2
# input 120 = 0.0
# input 121 = 0.2
# input 122 = 0.0
# input 123 = 0.0
# input 124 = 0.0
# input 125 = 0.0
# input 126 = 0.2
# input 127 = 0.0
# input 128 = 0.0
# input 129 = 0.2
# input 130 = 0.0
# input 131 = 0.2
# input 132 = 0.2
# input 133 = 0.2
# input 134 = 0.0
# input 135 = 0.2
# input 136 = 0.0
# input 137 = 0.0
# input 138 = 0.0
# input 139 = 0.2
# input 140 = 0.2
# input 141 = 0.2
# input 142 = 0.0
# input 143 = 0.0
# input 144 = 0.2
# input 145 = 0.2
# input 146 = 0.0
# input 147 = 0.0
# input 148 = 0.0
# input 149 = 0.0
# input 150 = 0.2
# input 151 = 0.2
# input 152 = 0.2
# input 153 = 0.2
# input 154 = 0.2
# input 155 = 0.2
# input 156 = 0.2
# input 157 = 0.2
# input 158 = 0.2
# input 159 = 0.2
# input 160 = 0.2
# input 161 = 0.2
# input 162 = 0.0
# input 163 = 0.0
# input 164 = 0.2
# input 165 = 0.2
# input 166 = 0.0
# input 167 = 0.2
# input 168 = 0.2
# input 169 = 0.2
# input 170 = 0.0
# input 171 = 0.0
# input 172 = 0.0
# input 173 = 0.0
# input 174 = 0.0
# input 175 = 0.0
# input 176 = 0.0
# input 177 = 0.0
# input 178 = 0.2
# input 179 = 0.2
# input 180 = 0.0
# input 181 = 0.2
# input 182 = 0.2
# input 183 = 0.2
# input 184 = 0.2
# input 185 = 0.2
# input 186 = 0.0
# input 187 = 0.2
# input 188 = 0.2
# input 189 = 0.0
# input 190 = 0.2
# input 191 = 0.2
# input 192 = 0.2
# input 193 = 0.2
# input 194 = 0.2
# input 195 = 0.2
# input 196 = 0.2
# input 197 = 0.2
# input 198 = 0.0
# input 199 = 0.0
# input 200 = 0.0
# input 201 = 0.2
# input 202 = 0.1294117748737335
# input 203 = 0.5254902124404908
# input 204 = 0.42352943420410155
# input 205 = 0.39215688705444335
# input 206 = 0.035294118523597706
# input 207 = 0.0
# input 208 = 0.0
# input 209 = 0.0
# input 210 = 0.18645195626612757
# input 211 = 0.2
# input 212 = 0.2
# input 213 = 0.0
# input 214 = 0.0
# input 215 = 0.0
# input 216 = 0.0
# input 217 = 0.0
# input 218 = 0.0
# input 219 = 0.0
# input 220 = 0.2
# input 221 = 0.0
# input 222 = 0.0
# input 223 = 0.0
# input 224 = 0.2
# input 225 = 0.2
# input 226 = 0.0
# input 227 = 0.2
# input 228 = 0.2
# input 229 = 0.0
# input 230 = 0.67058824300766
# input 231 = 0.7960784316062928
# input 232 = 0.7960784316062928
# input 233 = 0.7960784316062928
# input 234 = 0.7960784316062928
# input 235 = 0.7450980424880982
# input 236 = 0.5764706015586853
# input 237 = 0.5764706015586853
# input 238 = 0.5764706015586853
# input 239 = 0.5764706015586853
# input 240 = 0.5764706015586853
# input 241 = 0.5764706015586853
# input 242 = 0.5764706015586853
# input 243 = 0.5764706015586853
# input 244 = 0.4666666865348816
# input 245 = 0.003921571373939503
# input 246 = 0.0
# input 247 = 0.0
# input 248 = 0.2
# input 249 = 0.2
# input 250 = 0.0
# input 251 = 0.0
# input 252 = 0.0
# input 253 = 0.2
# input 254 = 0.0
# input 255 = 0.2
# input 256 = 0.2
# input 257 = 0.0
# input 258 = 0.46274511218070985
# input 259 = 0.24705882668495177
# input 260 = 0.0823529541492462
# input 261 = 0.24705882668495177
# input 262 = 0.43921570777893065
# input 263 = 0.6901960849761963
# input 264 = 0.7960784316062928
# input 265 = 0.6823529481887818
# input 266 = 0.7960784316062928
# input 267 = 0.7960784316062928
# input 268 = 0.7960784316062928
# input 269 = 0.7803921580314637
# input 270 = 0.6980392217636109
# input 271 = 0.7960784316062928
# input 272 = 0.7960784316062928
# input 273 = 0.3490196347236633
# input 274 = 0.0
# input 275 = 0.0
# input 276 = 0.2
# input 277 = 0.0
# input 278 = 0.2
# input 279 = 0.2
# input 280 = 0.2
# input 281 = 0.2
# input 282 = 0.0
# input 283 = 0.0
# input 284 = 0.2
# input 285 = 0.0
# input 286 = 0.0
# input 287 = 0.0
# input 288 = 0.0
# input 289 = 0.0
# input 290 = 0.0
# input 291 = 0.0
# input 292 = 0.4588235437870026
# input 293 = 0.17153901638887825
# input 294 = 0.06274511218070983
# input 295 = 0.06274511218070983
# input 296 = 0.06274511218070983
# input 297 = 0.03137255012989043
# input 298 = 0.0
# input 299 = 0.7254902005195618
# input 300 = 0.7960784316062928
# input 301 = 0.21568627953529357
# input 302 = 0.0
# input 303 = 0.2
# input 304 = 0.2
# input 305 = 0.2
# input 306 = 0.2
# input 307 = 0.0
# input 308 = 0.0
# input 309 = 0.0
# input 310 = 0.2
# input 311 = 0.0
# input 312 = 0.0
# input 313 = 0.0
# input 314 = 0.0
# input 315 = 0.0
# input 316 = 0.2
# input 317 = 0.2
# input 318 = 0.2
# input 319 = 0.2
# input 320 = 0.006763952620839648
# input 321 = 0.0
# input 322 = 0.0
# input 323 = 0.0
# input 324 = 0.0
# input 325 = 0.2
# input 326 = 0.12549020648002623
# input 327 = 0.7921568632125855
# input 328 = 0.6196078538894654
# input 329 = 0.0
# input 330 = 0.0
# input 331 = 0.0
# input 332 = 0.2
# input 333 = 0.0
# input 334 = 0.0
# input 335 = 0.2
# input 336 = 0.0
# input 337 = 0.0
# input 338 = 0.0
# input 339 = 0.0
# input 340 = 0.2
# input 341 = 0.2
# input 342 = 0.0
# input 343 = 0.0
# input 344 = 0.2
# input 345 = 0.0
# input 346 = 0.0
# input 347 = 0.19265823667905874
# input 348 = 0.19417491609540846
# input 349 = 0.2
# input 350 = 0.2
# input 351 = 0.0
# input 352 = 0.0
# input 353 = 0.28627451211214067
# input 354 = 1.0
# input 355 = 0.8
# input 356 = 0.12549020648002623
# input 357 = 0.0
# input 358 = 0.0
# input 359 = 0.0
# input 360 = 0.0
# input 361 = 0.0
# input 362 = 0.0
# input 363 = 0.2
# input 364 = 0.0
# input 365 = 0.0
# input 366 = 0.0
# input 367 = 0.0
# input 368 = 0.0
# input 369 = 0.0
# input 370 = 0.0
# input 371 = 0.0
# input 372 = 0.2
# input 373 = 0.2
# input 374 = 0.0
# input 375 = 0.0
# input 376 = 0.2
# input 377 = 0.2
# input 378 = 0.034300934185892314
# input 379 = 0.0
# input 380 = 0.0
# input 381 = 0.7058823823928833
# input 382 = 0.7960784316062928
# input 383 = 0.7333333373069764
# input 384 = 0.0
# input 385 = 0.0
# input 386 = 0.2
# input 387 = 0.0
# input 388 = 0.0
# input 389 = 0.0
# input 390 = 0.0
# input 391 = 0.0
# input 392 = 0.0
# input 393 = 0.0
# input 394 = 0.2
# input 395 = 0.2
# input 396 = 0.2
# input 397 = 0.0
# input 398 = 0.0
# input 399 = 0.0
# input 400 = 0.2
# input 401 = 0.0
# input 402 = 0.0
# input 403 = 0.0
# input 404 = 0.0
# input 405 = 0.2
# input 406 = 0.0
# input 407 = 0.0
# input 408 = 0.03137255012989043
# input 409 = 1.0
# input 410 = 0.7960784316062928
# input 411 = 0.04313725531101226
# input 412 = 0.0
# input 413 = 0.0
# input 414 = 0.0
# input 415 = 0.0
# input 416 = 0.0
# input 417 = 0.0
# input 418 = 0.2
# input 419 = 0.0
# input 420 = 0.2
# input 421 = 0.0
# input 422 = 0.0
# input 423 = 0.0
# input 424 = 0.2
# input 425 = 0.0
# input 426 = 0.0
# input 427 = 0.0
# input 428 = 0.17931833183255713
# input 429 = 0.0
# input 430 = 0.0
# input 431 = 0.0
# input 432 = 0.2
# input 433 = 0.2
# input 434 = 0.2
# input 435 = 0.2
# input 436 = 0.3215686559677124
# input 437 = 0.7960784316062928
# input 438 = 0.5333333492279053
# input 439 = 0.0
# input 440 = 0.0
# input 441 = 0.0
# input 442 = 0.2
# input 443 = 0.2
# input 444 = 0.0
# input 445 = 0.0
# input 446 = 0.0
# input 447 = 0.2
# input 448 = 0.0
# input 449 = 0.0
# input 450 = 0.2
# input 451 = 0.2
# input 452 = 0.2
# input 453 = 0.0
# input 454 = 0.0
# input 455 = 0.0
# input 456 = 0.2
# input 457 = 0.2
# input 458 = 0.2
# input 459 = 0.2
# input 460 = 0.0
# input 461 = 0.2
# input 462 = 0.2
# input 463 = 0.22774778343162277
# input 464 = 0.6039215803146363
# input 465 = 0.7725490212440491
# input 466 = 0.027450981736183155
# input 467 = 0.0
# input 468 = 0.0
# input 469 = 0.0
# input 470 = 0.2
# input 471 = 0.2
# input 472 = 0.0
# input 473 = 0.2
# input 474 = 0.2
# input 475 = 0.0
# input 476 = 0.2
# input 477 = 0.0
# input 478 = 0.0
# input 479 = 0.2
# input 480 = 0.2
# input 481 = 0.0
# input 482 = 0.0
# input 483 = 0.0
# input 484 = 0.0
# input 485 = 0.0
# input 486 = 0.2
# input 487 = 0.2
# input 488 = 0.008367858836853596
# input 489 = 0.0
# input 490 = 0.0
# input 491 = 0.2941176474094391
# input 492 = 0.7960784316062928
# input 493 = 0.601093566087574
# input 494 = 0.0
# input 495 = 0.0
# input 496 = 0.0
# input 497 = 0.2
# input 498 = 0.0
# input 499 = 0.2
# input 500 = 0.0
# input 501 = 0.0
# input 502 = 0.2
# input 503 = 0.0
# input 504 = 0.2
# input 505 = 0.0
# input 506 = 0.2
# input 507 = 0.0
# input 508 = 0.0
# input 509 = 0.2
# input 510 = 0.0
# input 511 = 0.0
# input 512 = 0.0
# input 513 = 0.2
# input 514 = 0.04420343577638274
# input 515 = 0.0
# input 516 = 0.2
# input 517 = 0.0
# input 518 = 0.09411765933036803
# input 519 = 0.7843137264251709
# input 520 = 0.7411764740943909
# input 521 = 0.02352941334247588
# input 522 = 0.0
# input 523 = 0.0
# input 524 = 0.2
# input 525 = 0.2
# input 526 = 0.0
# input 527 = 0.2
# input 528 = 0.0
# input 529 = 0.0
# input 530 = 0.0
# input 531 = 0.0
# input 532 = 0.2
# input 533 = 0.2
# input 534 = 0.0
# input 535 = 0.0
# input 536 = 0.0
# input 537 = 0.0
# input 538 = 0.0
# input 539 = 0.0
# input 540 = 0.16791527474186224
# input 541 = 0.2
# input 542 = 0.2
# input 543 = 0.2
# input 544 = 0.2
# input 545 = 0.0
# input 546 = 0.6666666746139527
# input 547 = 0.7960784316062928
# input 548 = 0.4509804129600525
# input 549 = 0.2
# input 550 = 0.2
# input 551 = 0.0
# input 552 = 0.0
# input 553 = 0.2
# input 554 = 0.2
# input 555 = 0.0
# input 556 = 0.0
# input 557 = 0.0
# input 558 = 0.2
# input 559 = 0.0
# input 560 = 0.0
# input 561 = 0.0
# input 562 = 0.0
# input 563 = 0.2
# input 564 = 0.0
# input 565 = 0.0
# input 566 = 0.0
# input 567 = 0.2
# input 568 = 0.2
# input 569 = 0.2
# input 570 = 0.10806633008942634
# input 571 = 0.0
# input 572 = 0.0
# input 573 = 0.7122037691764879
# input 574 = 0.7960784316062928
# input 575 = 1.0
# input 576 = 0.33725490868091584
# input 577 = 0.2
# input 578 = 0.2
# input 579 = 0.0
# input 580 = 0.0
# input 581 = 0.2
# input 582 = 0.0
# input 583 = 0.0
# input 584 = 0.2
# input 585 = 0.2
# input 586 = 0.0
# input 587 = 0.0
# input 588 = 0.0
# input 589 = 0.0
# input 590 = 0.0
# input 591 = 0.2
# input 592 = 0.2
# input 593 = 0.0
# input 594 = 0.2
# input 595 = 0.2
# input 596 = 0.2
# input 597 = 0.2
# input 598 = 0.2
# input 599 = 0.2
# input 600 = 0.34901961386203767
# input 601 = 0.7960784316062928
# input 602 = 1.0
# input 603 = 0.5019607961177825
# input 604 = 0.2
# input 605 = 0.2
# input 606 = 0.0
# input 607 = 0.2
# input 608 = 0.2
# input 609 = 0.0
# input 610 = 0.0
# input 611 = 0.2
# input 612 = 0.0
# input 613 = 0.0
# input 614 = 0.0
# input 615 = 0.2
# input 616 = 0.0
# input 617 = 0.0
# input 618 = 0.2
# input 619 = 0.0
# input 620 = 0.0
# input 621 = 0.2
# input 622 = 0.2
# input 623 = 0.2
# input 624 = 0.2
# input 625 = 0.2
# input 626 = 0.2
# input 627 = 0.32156862765550615
# input 628 = 1.0
# input 629 = 1.0
# input 630 = 0.650980395078659
# input 631 = 0.20392156885936857
# input 632 = 0.0
# input 633 = 0.0
# input 634 = 0.2
# input 635 = 0.0
# input 636 = 0.2
# input 637 = 0.2
# input 638 = 0.0
# input 639 = 0.2
# input 640 = 0.0
# input 641 = 0.0
# input 642 = 0.0
# input 643 = 0.0
# input 644 = 0.0
# input 645 = 0.2
# input 646 = 0.0
# input 647 = 0.0
# input 648 = 0.0
# input 649 = 0.2
# input 650 = 0.0
# input 651 = 0.0
# input 652 = 0.2
# input 653 = 0.0
# input 654 = 0.0
# input 655 = 0.3215686559677124
# input 656 = 0.7960784316062928
# input 657 = 0.7960784316062928
# input 658 = 0.003921571373939503
# input 659 = 0.2
# input 660 = 0.0
# input 661 = 0.0
# input 662 = 0.0
# input 663 = 0.0
# input 664 = 0.2
# input 665 = 0.2
# input 666 = 0.2
# input 667 = 0.2
# input 668 = 0.0
# input 669 = 0.2
# input 670 = 0.0
# input 671 = 0.0
# input 672 = 0.2
# input 673 = 0.0
# input 674 = 0.2
# input 675 = 0.0
# input 676 = 0.2
# input 677 = 0.0
# input 678 = 0.2
# input 679 = 0.0
# input 680 = 0.0
# input 681 = 0.0
# input 682 = 0.03921568691730498
# input 683 = 0.7490196108818055
# input 684 = 0.7960784316062928
# input 685 = 0.7960784316062928
# input 686 = 0.003921571373939503
# input 687 = 0.0
# input 688 = 0.0
# input 689 = 0.2
# input 690 = 0.0
# input 691 = 0.2
# input 692 = 0.2
# input 693 = 0.2
# input 694 = 0.0
# input 695 = 0.2
# input 696 = 0.2
# input 697 = 0.0
# input 698 = 0.0
# input 699 = 0.2
# input 700 = 0.2
# input 701 = 0.0
# input 702 = 0.0
# input 703 = 0.2
# input 704 = 0.0
# input 705 = 0.0
# input 706 = 0.0
# input 707 = 0.0
# input 708 = 0.0
# input 709 = 0.0
# input 710 = 0.2745098054409027
# input 711 = 0.7960784316062928
# input 712 = 0.7960784316062928
# input 713 = 0.6588235378265381
# input 714 = 0.0
# input 715 = 0.0
# input 716 = 0.0
# input 717 = 0.0
# input 718 = 0.0
# input 719 = 0.0
# input 720 = 0.2
# input 721 = 0.0
# input 722 = 0.2
# input 723 = 0.0
# input 724 = 0.2
# input 725 = 0.0
# input 726 = 0.0
# input 727 = 0.0
# input 728 = 0.2
# input 729 = 0.0
# input 730 = 0.0
# input 731 = 0.0
# input 732 = 0.0
# input 733 = 0.0
# input 734 = 0.0
# input 735 = 0.0
# input 736 = 0.0
# input 737 = 0.0
# input 738 = 0.6745098054409027
# input 739 = 1.0
# input 740 = 0.6117647171020508
# input 741 = 0.0
# input 742 = 0.0
# input 743 = 0.0
# input 744 = 0.0
# input 745 = 0.2
# input 746 = 0.0
# input 747 = 0.0
# input 748 = 0.2
# input 749 = 0.0
# input 750 = 0.0
# input 751 = 0.0
# input 752 = 0.2
# input 753 = 0.2
# input 754 = 0.0
# input 755 = 0.0
# input 756 = 0.0
# input 757 = 0.0
# input 758 = 0.2
# input 759 = 0.0
# input 760 = 0.0
# input 761 = 0.0
# input 762 = 0.0
# input 763 = 0.0
# input 764 = 0.0
# input 765 = 0.2
# input 766 = 0.0
# input 767 = 0.0
# input 768 = 0.0
# input 769 = 0.0
# input 770 = 0.0
# input 771 = 0.2
# input 772 = 0.2
# input 773 = 0.0
# input 774 = 0.2
# input 775 = 0.0
# input 776 = 0.0
# input 777 = 0.2
# input 778 = 0.0
# input 779 = 0.0
# input 780 = 0.2
# input 781 = 0.2
# input 782 = 0.0
# input 783 = 0.0
# output 0 = -2.7562064484348547
# output 1 = -2.1639882929325323
# output 2 = 0.3477515147857214
# output 3 = 0.05667069054650513
# output 4 = -4.135824949034738
# output 5 = -1.7265873704568224
# output 6 = -4.4286282320284425
# output 7 = 0.3476515147628204
# output 8 = -1.9383472219422457
# output 9 = -2.0985319892683787
# sat
# input 0 = 0.2
# input 1 = 0.2
# input 2 = 0.0
# input 3 = 0.0
# input 4 = 0.2
# input 5 = 0.0
# input 6 = 0.2
# input 7 = 0.2
# input 8 = 0.0
# input 9 = 0.2
# input 10 = 0.0
# input 11 = 0.0
# input 12 = 0.0
# input 13 = 0.2
# input 14 = 0.2
# input 15 = 0.2
# input 16 = 0.0
# input 17 = 0.2
# input 18 = 0.2
# input 19 = 0.2
# input 20 = 0.2
# input 21 = 0.2
# input 22 = 0.0
# input 23 = 0.0
# input 24 = 0.0
# input 25 = 0.0
# input 26 = 0.0
# input 27 = 0.0
# input 28 = 0.0
# input 29 = 0.2
# input 30 = 0.0
# input 31 = 0.0
# input 32 = 0.0
# input 33 = 0.0
# input 34 = 0.0
# input 35 = 0.0
# input 36 = 0.0
# input 37 = 0.2
# input 38 = 0.0
# input 39 = 0.0
# input 40 = 0.2
# input 41 = 0.2
# input 42 = 0.0
# input 43 = 0.2
# input 44 = 0.0
# input 45 = 0.2
# input 46 = 0.2
# input 47 = 0.0
# input 48 = 0.0
# input 49 = 0.2
# input 50 = 0.0
# input 51 = 0.2
# input 52 = 0.0
# input 53 = 0.0
# input 54 = 0.0
# input 55 = 0.0
# input 56 = 0.2
# input 57 = 0.0
# input 58 = 0.2
# input 59 = 0.0
# input 60 = 0.0
# input 61 = 0.2
# input 62 = 0.0
# input 63 = 0.0
# input 64 = 0.0
# input 65 = 0.2
# input 66 = 0.2
# input 67 = 0.2
# input 68 = 0.2
# input 69 = 0.0
# input 70 = 0.2
# input 71 = 0.0
# input 72 = 0.2
# input 73 = 0.2
# input 74 = 0.0
# input 75 = 0.0
# input 76 = 0.2
# input 77 = 0.2
# input 78 = 0.0
# input 79 = 0.2
# input 80 = 0.2
# input 81 = 0.2
# input 82 = 0.2
# input 83 = 0.2
# input 84 = 0.0
# input 85 = 0.0
# input 86 = 0.0
# input 87 = 0.2
# input 88 = 0.0
# input 89 = 0.2
# input 90 = 0.0
# input 91 = 0.0
# input 92 = 0.2
# input 93 = 0.0
# input 94 = 0.2
# input 95 = 0.0
# input 96 = 0.2
# input 97 = 0.0
# input 98 = 0.0
# input 99 = 0.0
# input 100 = 0.2
# input 101 = 0.0
# input 102 = 0.0
# input 103 = 0.0
# input 104 = 0.0
# input 105 = 0.2
# input 106 = 0.2
# input 107 = 0.0
# input 108 = 0.0
# input 109 = 0.0
# input 110 = 0.2
# input 111 = 0.0
# input 112 = 0.2
# input 113 = 0.2
# input 114 = 0.2
# input 115 = 0.2
# input 116 = 0.0
# input 117 = 0.0
# input 118 = 0.2
# input 119 = 0.0
# input 120 = 0.2
# input 121 = 0.0
# input 122 = 0.0
# input 123 = 0.0
# input 124 = 0.0
# input 125 = 0.0
# input 126 = 0.2
# input 127 = 0.0
# input 128 = 0.2
# input 129 = 0.0
# input 130 = 0.0
# input 131 = 0.2
# input 132 = 0.2
# input 133 = 0.2
# input 134 = 0.0
# input 135 = 0.2
# input 136 = 0.0
# input 137 = 0.0
# input 138 = 0.0
# input 139 = 0.0
# input 140 = 0.2
# input 141 = 0.2
# input 142 = 0.0
# input 143 = 0.2
# input 144 = 0.2
# input 145 = 0.0
# input 146 = 0.0
# input 147 = 0.2
# input 148 = 0.2
# input 149 = 0.0
# input 150 = 0.0
# input 151 = 0.2
# input 152 = 0.2
# input 153 = 0.2
# input 154 = 0.2
# input 155 = 0.19016166609545263
# input 156 = 0.2
# input 157 = 0.2
# input 158 = 0.2
# input 159 = 0.2
# input 160 = 0.0
# input 161 = 0.2
# input 162 = 0.2
# input 163 = 0.0
# input 164 = 0.2
# input 165 = 0.0
# input 166 = 0.2
# input 167 = 0.2
# input 168 = 0.0
# input 169 = 0.2
# input 170 = 0.2
# input 171 = 0.0
# input 172 = 0.2
# input 173 = 0.2
# input 174 = 0.2
# input 175 = 0.0
# input 176 = 0.0
# input 177 = 0.0
# input 178 = 0.0
# input 179 = 0.0
# input 180 = 0.0
# input 181 = 0.0
# input 182 = 0.2
# input 183 = 0.2
# input 184 = 0.2
# input 185 = 0.2
# input 186 = 0.2
# input 187 = 0.2
# input 188 = 0.2
# input 189 = 0.2
# input 190 = 0.0
# input 191 = 0.2
# input 192 = 0.0
# input 193 = 0.2
# input 194 = 0.2
# input 195 = 0.2
# input 196 = 0.0
# input 197 = 0.0
# input 198 = 0.2
# input 199 = 0.0
# input 200 = 0.0
# input 201 = 0.2
# input 202 = 0.1294117748737335
# input 203 = 0.5254902124404908
# input 204 = 0.42352943420410155
# input 205 = 0.39215688705444335
# input 206 = 0.035294118523597706
# input 207 = 0.0
# input 208 = 0.0
# input 209 = 0.2
# input 210 = 0.2
# input 211 = 0.12587756297343866
# input 212 = 0.2
# input 213 = 0.2
# input 214 = 0.2
# input 215 = 0.1636373803831473
# input 216 = 0.2
# input 217 = 0.2
# input 218 = 0.0
# input 219 = 0.2
# input 220 = 0.0
# input 221 = 0.2
# input 222 = 0.0
# input 223 = 0.0
# input 224 = 0.0
# input 225 = 0.2
# input 226 = 0.2
# input 227 = 0.2
# input 228 = 0.0
# input 229 = 0.0
# input 230 = 1.0
# input 231 = 0.7960784316062928
# input 232 = 0.7960784316062928
# input 233 = 0.7960784316062928
# input 234 = 0.7960784316062928
# input 235 = 1.0
# input 236 = 0.9764706015586853
# input 237 = 0.5764706015586853
# input 238 = 0.9764706015586853
# input 239 = 0.9764706015586853
# input 240 = 0.9764706015586853
# input 241 = 0.9764706015586853
# input 242 = 0.5764706015586853
# input 243 = 0.9764706015586853
# input 244 = 0.8666666865348815
# input 245 = 0.003921571373939503
# input 246 = 0.2
# input 247 = 0.0
# input 248 = 0.0
# input 249 = 0.2
# input 250 = 0.0
# input 251 = 0.0
# input 252 = 0.0
# input 253 = 0.0
# input 254 = 0.0
# input 255 = 0.2
# input 256 = 0.0
# input 257 = 0.2
# input 258 = 0.06274511218070983
# input 259 = 0.24705882668495177
# input 260 = 0.0823529541492462
# input 261 = 0.24705882668495177
# input 262 = 0.43921570777893065
# input 263 = 1.0
# input 264 = 1.0
# input 265 = 0.6823529481887818
# input 266 = 0.7960784316062928
# input 267 = 1.0
# input 268 = 0.7960784316062928
# input 269 = 0.7803921580314637
# input 270 = 0.6980392217636109
# input 271 = 0.7960784316062928
# ...
# input 735 = 0.0
# input 736 = 0.0
# input 737 = 0.0
# input 738 = 0.6745098054409027
# input 739 = 1.0
# input 740 = 0.6117647171020508
# input 741 = 0.27058823853731157
# input 742 = 0.2
# input 743 = 0.2
# input 744 = 0.0
# input 745 = 0.2
# input 746 = 0.2
# input 747 = 0.2
# input 748 = 0.2
# input 749 = 0.2
# input 750 = 0.2
# input 751 = 0.2
# input 752 = 0.2
# input 753 = 0.2
# input 754 = 0.2
# input 755 = 0.2
# input 756 = 0.2
# input 757 = 0.2
# input 758 = 0.2
# input 759 = 0.2
# input 760 = 0.2
# input 761 = 0.2
# input 762 = 0.2
# input 763 = 0.2
# input 764 = 0.2
# input 765 = 0.2
# input 766 = 0.2
# input 767 = 0.2
# input 768 = 0.2
# input 769 = 0.2
# input 770 = 0.2
# input 771 = 0.2
# input 772 = 0.0
# input 773 = 0.2
# input 774 = 0.2
# input 775 = 0.2
# input 776 = 0.2
# input 777 = 0.2
# input 778 = 0.2
# input 779 = 0.2
# input 780 = 0.2
# input 781 = 0.2
# input 782 = 0.2
# input 783 = 0.2
# output 0 = -2.71137693653222
# output 1 = -3.0421011353436405
# output 2 = -1.4991576144529979
# output 3 = -0.9883870654674584
# output 4 = -2.3242645371005053
# output 5 = -1.633995183214609
# output 6 = -3.7768235237780976
# output 7 = -0.8244570767422079
# output 8 = -2.097498462072749
# output 9 = -0.8243570767422079
# unsat
# unsat
# unsat
# unsat
# unsat
# sat
# input 0 = 0.0
# input 1 = 0.0
# input 2 = 0.0
# input 3 = 0.0
# input 4 = 0.0
# input 5 = 0.0
# input 6 = 0.0
# input 7 = 0.0
# input 8 = 0.0
# input 9 = 0.0
# input 10 = 0.0
# input 11 = 0.0
# input 12 = 0.0
# input 13 = 0.0
# input 14 = 0.0
# input 15 = 0.0
# input 16 = 0.0
# input 17 = 0.0
# input 18 = 0.0
# input 19 = 0.0
# input 20 = 0.0
# input 21 = 0.0
# input 22 = 0.0
# input 23 = 0.0
# input 24 = 0.0
# input 25 = 0.0
# input 26 = 0.0
# input 27 = 0.0
# input 28 = 0.0
# input 29 = 0.0
# input 30 = 0.0
# input 31 = 0.0
# input 32 = 0.0
# input 33 = 0.0
# input 34 = 0.0
# input 35 = 0.0
# input 36 = 0.0
# input 37 = 0.0
# input 38 = 0.0
# input 39 = 0.0
# input 40 = 0.0
# input 41 = 0.0
# input 42 = 0.0
# input 43 = 0.0
# input 44 = 0.0
# input 45 = 0.0
# input 46 = 0.0
# input 47 = 0.0
# input 48 = 0.0
# input 49 = 0.0
# input 50 = 0.0
# input 51 = 0.0
# input 52 = 0.0
# input 53 = 0.0
# input 54 = 0.0
# input 55 = 0.0
# input 56 = 0.0
# input 57 = 0.0
# input 58 = 0.0
# input 59 = 0.0
# input 60 = 0.0
# input 61 = 0.0
# input 62 = 0.0
# input 63 = 0.0
# input 64 = 0.0
# input 65 = 0.0
# input 66 = 0.0
# input 67 = 0.0
# input 68 = 0.0
# input 69 = 0.0
# input 70 = 0.0
# input 71 = 0.0
# input 72 = 0.0
# input 73 = 0.0
# input 74 = 0.0
# input 75 = 0.0
# input 76 = 0.0
# input 77 = 0.0
# input 78 = 0.0
# input 79 = 0.0
# input 80 = 0.0
# input 81 = 0.0
# input 82 = 0.0
# input 83 = 0.0
# input 84 = 0.0
# input 85 = 0.0
# input 86 = 0.0
# input 87 = 0.0
# input 88 = 0.0
# input 89 = 0.0
# input 90 = 0.0
# input 91 = 0.0
# input 92 = 0.0
# input 93 = 0.0
# input 94 = 0.2549019634723663
# input 95 = 0.2901960790157318
# input 96 = 0.47058825492858886
# input 97 = 0.8
# input 98 = 0.8
# input 99 = 0.3882353186607361
# input 100 = 0.164705890417099
# input 101 = 0.0
# input 102 = 0.0
# input 103 = 0.2
# input 104 = 0.0
# input 105 = 0.0
# input 106 = 0.0
# input 107 = 0.0
# input 108 = 0.0
# input 109 = 0.0
# input 110 = 0.0
# input 111 = 0.0
# input 112 = 0.0
# input 113 = 0.0
# input 114 = 0.0
# input 115 = 0.0
# input 116 = 0.0
# input 117 = 0.0
# input 118 = 0.0
# input 119 = 0.0
# input 120 = 0.0
# input 121 = 0.4627451181411743
# input 122 = 0.7921568632125855
# input 123 = 0.7921568632125855
# input 124 = 0.7921568632125855
# input 125 = 0.7921568632125855
# input 126 = 0.7921568632125855
# input 127 = 0.7921568632125855
# input 128 = 0.7971731682827355
# input 129 = 0.0
# input 130 = 0.0
# input 131 = 0.0
# input 132 = 0.09097452006724638
# input 133 = 0.0
# input 134 = 0.0
# input 135 = 0.0
# input 136 = 0.0
# input 137 = 0.0
# input 138 = 0.0
# input 139 = 0.0
# input 140 = 0.0
# input 141 = 0.0
# input 142 = 0.0
# input 143 = 0.0
# input 144 = 0.0
# input 145 = 0.0
# input 146 = 0.0
# input 147 = 0.0
# input 148 = 0.4627451181411743
# input 149 = 0.7921568632125855
# input 150 = 0.7921568632125855
# input 151 = 0.7921568632125855
# input 152 = 0.6352941274642945
# input 153 = 0.35686277151107787
# input 154 = 0.49019609689712523
# input 155 = 0.7921568632125855
# input 156 = 0.7921568632125855
# input 157 = 0.27843137383461
# input 158 = 0.0
# input 159 = 0.0
# input 160 = 0.0
# input 161 = 0.0
# input 162 = 0.0
# input 163 = 0.0
# input 164 = 0.0
# input 165 = 0.0
# input 166 = 0.0
# input 167 = 0.0
# input 168 = 0.0
# input 169 = 0.0
# input 170 = 0.0
# input 171 = 0.0
# input 172 = 0.0
# input 173 = 0.0
# input 174 = 0.0
# input 175 = 0.003921571373939503
# input 176 = 0.7803921580314637
# input 177 = 0.7921568632125855
# input 178 = 0.6235294222831727
# input 179 = 0.0
# input 180 = 0.0
# input 181 = 0.0
# input 182 = 0.0
# input 183 = 0.6078431487083436
# input 184 = 0.7921568632125855
# input 185 = 0.3490196347236633
# input 186 = 0.0
# input 187 = 0.0
# input 188 = 0.0
# input 189 = 0.0
# input 190 = 0.0
# input 191 = 0.0
# input 192 = 0.0
# input 193 = 0.0
# input 194 = 0.0
# input 195 = 0.0
# input 196 = 0.0
# input 197 = 0.0
# input 198 = 0.0
# input 199 = 0.0
# input 200 = 0.0
# input 201 = 0.0
# input 202 = 0.0
# input 203 = 0.10196079611778258
# input 204 = 0.7843137264251709
# input 205 = 0.6235294222831727
# input 206 = 0.0
# input 207 = 0.0
# input 208 = 0.0
# input 209 = 0.0
# input 210 = 0.27843137383461
# input 211 = 0.7725490212440491
# input 212 = 0.7921568632125855
# input 213 = 0.05490197539329528
# input 214 = 0.0
# input 215 = 0.0
# input 216 = 0.0
# input 217 = 0.0
# input 218 = 0.0
# input 219 = 0.0
# input 220 = 0.0
# input 221 = 0.0
# input 222 = 0.0
# input 223 = 0.0
# input 224 = 0.0
# input 225 = 0.0
# input 226 = 0.0
# input 227 = 0.0
# input 228 = 0.0
# input 229 = 0.0
# input 230 = 0.0
# input 231 = 0.0
# input 232 = 0.0
# input 233 = 0.0
# input 234 = 0.0
# input 235 = 0.0
# input 236 = 0.2
# input 237 = 0.0
# input 238 = 0.6196078538894654
# input 239 = 0.7921568632125855
# input 240 = 0.7921568632125855
# input 241 = 0.05490197539329528
# input 242 = 0.0
# input 243 = 0.0
# input 244 = 0.0
# input 245 = 0.0
# input 246 = 0.0
# input 247 = 0.0
# input 248 = 0.0
# input 249 = 0.0
# input 250 = 0.0
# input 251 = 0.0
# input 252 = 0.0
# input 253 = 0.0
# input 254 = 0.0
# input 255 = 0.0
# input 256 = 0.0
# input 257 = 0.0
# input 258 = 0.0
# input 259 = 0.0
# input 260 = 0.0
# input 261 = 0.2
# input 262 = 0.2
# input 263 = 0.2
# input 264 = 0.2
# input 265 = 0.2588235318660736
# input 266 = 0.7686274528503418
# input 267 = 0.7921568632125855
# input 268 = 0.5764706015586853
# input 269 = 0.0
# input 270 = 0.0
# input 271 = 0.0
# input 272 = 0.0
# input 273 = 0.0
# input 274 = 0.0
# input 275 = 0.0
# input 276 = 0.0
# input 277 = 0.0
# input 278 = 0.0
# input 279 = 0.0
# input 280 = 0.0
# input 281 = 0.0
# input 282 = 0.0
# input 283 = 0.0
# input 284 = 0.0
# input 285 = 0.0
# input 286 = 0.0
# input 287 = 0.0
# input 288 = 0.0
# input 289 = 0.2
# input 290 = 0.0
# input 291 = 0.0
# input 292 = 0.0980392277240753
# input 293 = 0.7686274528503418
# input 294 = 0.7921568632125855
# input 295 = 0.7058823585510254
# input 296 = 0.04705882370471953
# input 297 = 0.0
# input 298 = 0.0
# input 299 = 0.0
# input 300 = 0.0
# input 301 = 0.0
# input 302 = 0.0
# input 303 = 0.0
# input 304 = 0.0
# input 305 = 0.0
# input 306 = 0.0
# input 307 = 0.0
# input 308 = 0.0
# input 309 = 0.0
# input 310 = 0.0
# input 311 = 0.0
# input 312 = 0.0
# input 313 = 0.0
# input 314 = 0.0
# input 315 = 0.0
# input 316 = 0.0
# input 317 = 0.0
# input 318 = 0.0
# input 319 = 0.0
# input 320 = 0.301960813999176
# input 321 = 0.7921568632125855
# input 322 = 0.7921568632125855
# input 323 = 0.3647059082984924
# input 324 = 0.0
# input 325 = 0.0
# input 326 = 0.0
# input 327 = 0.0
# input 328 = 0.0
# input 329 = 0.0
# input 330 = 0.0
# input 331 = 0.0
# input 332 = 0.0
# input 333 = 0.0
# input 334 = 0.0
# input 335 = 0.0
# input 336 = 0.0
# input 337 = 0.0
# input 338 = 0.0
# input 339 = 0.0
# input 340 = 0.0
# input 341 = 0.0
# input 342 = 0.0
# input 343 = 0.0
# input 344 = 0.0
# input 345 = 0.0
# input 346 = 0.0
# input 347 = 0.5254736447255148
# input 348 = 0.7647058844566346
# input 349 = 0.7921568632125855
# input 350 = 0.42352943420410155
# input 351 = 0.0
# input 352 = 0.0
# input 353 = 0.0
# input 354 = 0.0
# input 355 = 0.0
# input 356 = 0.0
# input 357 = 0.0
# input 358 = 0.0
# input 359 = 0.0
# input 360 = 0.0
# input 361 = 0.0
# input 362 = 0.0
# input 363 = 0.0
# input 364 = 0.0
# input 365 = 0.0
# input 366 = 0.0
# input 367 = 0.0
# input 368 = 0.0
# input 369 = 0.0
# input 370 = 0.0
# input 371 = 0.0
# input 372 = 0.0
# input 373 = 0.0
# input 374 = 0.0
# input 375 = 0.7176470637321473
# input 376 = 0.7921568632125855
# input 377 = 0.71372549533844
# input 378 = 0.0
# input 379 = 0.0
# input 380 = 0.0
# input 381 = 0.0
# input 382 = 0.0
# input 383 = 0.0
# input 384 = 0.0
# input 385 = 0.0
# input 386 = 0.0
# input 387 = 0.0
# input 388 = 0.0
# input 389 = 0.0
# input 390 = 0.0
# input 391 = 0.0
# input 392 = 0.0
# input 393 = 0.0
# input 394 = 0.0
# input 395 = 0.0
# input 396 = 0.0
# input 397 = 0.0
# input 398 = 0.0
# input 399 = 0.0
# input 400 = 0.0
# input 401 = 0.0
# input 402 = 0.5764706015586853
# input 403 = 0.7921568632125855
# input 404 = 0.7921568632125855
# input 405 = 0.3529412031173706
# input 406 = 0.0
# input 407 = 0.0
# input 408 = 0.0
# input 409 = 0.0
# input 410 = 0.0
# input 411 = 0.0
# input 412 = 0.0
# input 413 = 0.0
# input 414 = 0.0
# input 415 = 0.0
# input 416 = 0.0
# input 417 = 0.0
# input 418 = 0.0
# input 419 = 0.0
# input 420 = 0.0
# input 421 = 0.0
# input 422 = 0.0
# input 423 = 0.0
# input 424 = 0.0
# input 425 = 0.0
# input 426 = 0.0
# input 427 = 0.0
# input 428 = 0.0
# input 429 = 0.10588236451148986
# input 430 = 0.7725490212440491
# input 431 = 0.7921568632125855
# input 432 = 0.5411764860153199
# input 433 = 0.0
# input 434 = 0.0
# input 435 = 0.0
# input 436 = 0.0
# input 437 = 0.0
# input 438 = 0.0
# input 439 = 0.0
# input 440 = 0.0
# input 441 = 0.0
# input 442 = 0.0
# input 443 = 0.0
# input 444 = 0.0
# input 445 = 0.0
# input 446 = 0.0
# input 447 = 0.0
# input 448 = 0.0
# input 449 = 0.0
# input 450 = 0.0
# input 451 = 0.0
# input 452 = 0.0
# input 453 = 0.0
# input 454 = 0.0
# input 455 = 0.0
# input 456 = 0.0
# input 457 = 0.5843137383460999
# input 458 = 0.7921568632125855
# input 459 = 0.7921568632125855
# input 460 = 0.3529412031173706
# input 461 = 0.0
# input 462 = 0.0
# input 463 = 0.0
# input 464 = 0.0
# input 465 = 0.0
# input 466 = 0.0
# input 467 = 0.0
# input 468 = 0.0
# input 469 = 0.0
# input 470 = 0.0
# input 471 = 0.0
# input 472 = 0.0
# input 473 = 0.0
# input 474 = 0.0
# input 475 = 0.0
# input 476 = 0.0
# input 477 = 0.0
# input 478 = 0.0
# input 479 = 0.0
# input 480 = 0.0
# input 481 = 0.0
# input 482 = 0.0
# input 483 = 0.0
# input 484 = 0.32549022436141967
# input 485 = 0.7921568632125855
# input 486 = 0.7921568632125855
# input 487 = 0.4784313917160034
# input 488 = 0.0
# input 489 = 0.0
# input 490 = 0.0
# input 491 = 0.0
# input 492 = 0.0
# input 493 = 0.0
# input 494 = 0.0
# input 495 = 0.0
# input 496 = 0.0
# input 497 = 0.0
# input 498 = 0.0
# input 499 = 0.0
# input 500 = 0.0
# input 501 = 0.0
# input 502 = 0.0
# input 503 = 0.0
# input 504 = 0.0
# input 505 = 0.0
# input 506 = 0.0
# input 507 = 0.0
# input 508 = 0.0
# input 509 = 0.0
# input 510 = 0.0
# input 511 = 0.0
# input 512 = 0.7725490212440491
# input 513 = 0.7921568632125855
# input 514 = 0.7921568632125855
# input 515 = 0.0
# input 516 = 0.0
# input 517 = 0.0
# input 518 = 0.0
# input 519 = 0.0
# input 520 = 0.0
# input 521 = 0.0
# input 522 = 0.0
# input 523 = 0.0
# input 524 = 0.0
# input 525 = 0.0
# input 526 = 0.0
# input 527 = 0.0
# input 528 = 0.0
# input 529 = 0.0
# input 530 = 0.0
# input 531 = 0.0
# input 532 = 0.0
# input 533 = 0.0
# input 534 = 0.0
# input 535 = 0.0
# input 536 = 0.0
# input 537 = 0.0
# input 538 = 0.0
# input 539 = 0.0
# input 540 = 0.7725490212440491
# input 541 = 0.7921568632125855
# input 542 = 0.7921568632125855
# input 543 = 0.0
# input 544 = 0.0
# input 545 = 0.0
# input 546 = 0.0
# input 547 = 0.0
# input 548 = 0.0
# input 549 = 0.0
# input 550 = 0.0
# input 551 = 0.0
# input 552 = 0.0
# input 553 = 0.0
# input 554 = 0.3882353186607361
# input 555 = 0.3882353186607361
# input 556 = 0.3882353186607361
# input 557 = 0.37647061347961425
# input 558 = 0.0
# input 559 = 0.0
# input 560 = 0.0
# input 561 = 0.0
# input 562 = 0.0
# input 563 = 0.0
# input 564 = 0.0
# input 565 = 0.0
# input 566 = 0.0
# input 567 = 0.0
# input 568 = 0.7725490212440491
# input 569 = 0.7921568632125855
# input 570 = 0.7921568632125855
# input 571 = 0.7921568632125855
# input 572 = 0.7921568632125855
# input 573 = 0.7921568632125855
# input 574 = 0.7921568632125855
# input 575 = 0.7921568632125855
# input 576 = 0.45882354974746703
# input 577 = 0.36078433990478515
# input 578 = 0.4509804129600525
# input 579 = 0.7921568632125855
# input 580 = 0.7921568632125855
# input 581 = 0.7921568632125855
# input 582 = 0.7921568632125855
# input 583 = 0.7921568632125855
# input 584 = 0.7921568632125855
# input 585 = 0.7921568632125855
# input 586 = 0.28235294222831725
# input 587 = 0.0
# input 588 = 0.0
# input 589 = 0.0
# input 590 = 0.0
# input 591 = 0.0
# input 592 = 0.0
# input 593 = 0.0
# input 594 = 0.0
# input 595 = 0.0
# input 596 = 0.4823529601097107
# input 597 = 0.7921568632125855
# input 598 = 0.7921568632125855
# input 599 = 0.7921568632125855
# input 600 = 0.7921568632125855
# input 601 = 0.7921568632125855
# input 602 = 0.7921568632125855
# input 603 = 0.7921568632125855
# input 604 = 0.7921568632125855
# input 605 = 0.7921568632125855
# input 606 = 0.7921568632125855
# input 607 = 0.7921568632125855
# input 608 = 0.7764705896377564
# input 609 = 0.7686274528503418
# input 610 = 0.7686274528503418
# input 611 = 0.4627451181411743
# input 612 = 0.2588235318660736
# input 613 = 0.2588235318660736
# input 614 = 0.02352941334247588
# input 615 = 0.0
# input 616 = 0.0
# input 617 = 0.0
# input 618 = 0.0
# input 619 = 0.0
# input 620 = 0.0
# input 621 = 0.0
# input 622 = 0.0
# input 623 = 0.0
# input 624 = 0.0
# input 625 = 0.2627451002597809
# input 626 = 0.28235294222831725
# input 627 = 0.28235294222831725
# input 628 = 0.28235294222831725
# input 629 = 0.4509804129600525
# input 630 = 0.7921568632125855
# input 631 = 0.7921568632125855
# input 632 = 0.7921568632125855
# input 633 = 0.40784316062927245
# input 634 = 0.28235294222831725
# input 635 = 0.28235294222831725
# input 636 = 0.0
# input 637 = 0.0
# input 638 = 0.0
# input 639 = 0.0
# input 640 = 0.0
# input 641 = 0.0
# input 642 = 0.0
# input 643 = 0.0
# input 644 = 0.0
# input 645 = 0.0
# input 646 = 0.0
# input 647 = 0.0
# input 648 = 0.0
# input 649 = 0.0
# input 650 = 0.0
# input 651 = 0.0
# input 652 = 0.0
# input 653 = 0.0
# input 654 = 0.0
# input 655 = 0.0
# input 656 = 0.0
# input 657 = 0.0
# input 658 = 0.2
# input 659 = 0.0
# input 660 = 0.0
# input 661 = 0.0
# input 662 = 0.0
# input 663 = 0.0
# input 664 = 0.0
# input 665 = 0.0
# input 666 = 0.0
# input 667 = 0.0
# input 668 = 0.0
# input 669 = 0.0
# input 670 = 0.0
# input 671 = 0.0
# input 672 = 0.0
# input 673 = 0.0
# input 674 = 0.0
# input 675 = 0.0
# input 676 = 0.0
# input 677 = 0.0
# input 678 = 0.0
# input 679 = 0.0
# input 680 = 0.0
# input 681 = 0.0
# input 682 = 0.0
# input 683 = 0.0
# input 684 = 0.0
# input 685 = 0.0
# input 686 = 0.0
# input 687 = 0.0
# input 688 = 0.0
# input 689 = 0.0
# input 690 = 0.0
# input 691 = 0.0
# input 692 = 0.0
# input 693 = 0.0
# input 694 = 0.0
# input 695 = 0.0
# input 696 = 0.0
# input 697 = 0.0
# input 698 = 0.0
# input 699 = 0.0
# input 700 = 0.0
# input 701 = 0.0
# input 702 = 0.0
# input 703 = 0.0
# input 704 = 0.0
# input 705 = 0.0
# input 706 = 0.0
# input 707 = 0.0
# input 708 = 0.0
# input 709 = 0.0
# input 710 = 0.0
# input 711 = 0.0
# input 712 = 0.0
# input 713 = 0.0
# input 714 = 0.0
# input 715 = 0.0
# input 716 = 0.0
# input 717 = 0.0
# input 718 = 0.0
# input 719 = 0.0
# input 720 = 0.0
# input 721 = 0.0
# input 722 = 0.0
# input 723 = 0.0
# input 724 = 0.0
# input 725 = 0.0
# input 726 = 0.0
# input 727 = 0.0
# input 728 = 0.0
# input 729 = 0.0
# input 730 = 0.0
# input 731 = 0.0
# input 732 = 0.0
# input 733 = 0.0
# input 734 = 0.0
# input 735 = 0.0
# input 736 = 0.0
# input 737 = 0.0
# input 738 = 0.0
# input 739 = 0.0
# input 740 = 0.0
# input 741 = 0.0
# input 742 = 0.0
# input 743 = 0.0
# input 744 = 0.0
# input 745 = 0.0
# input 746 = 0.0
# input 747 = 0.0
# input 748 = 0.0
# input 749 = 0.0
# input 750 = 0.0
# input 751 = 0.0
# input 752 = 0.0
# input 753 = 0.0
# input 754 = 0.0
# input 755 = 0.0
# input 756 = 0.0
# input 757 = 0.0
# input 758 = 0.0
# input 759 = 0.0
# input 760 = 0.0
# input 761 = 0.0
# input 762 = 0.0
# input 763 = 0.0
# input 764 = 0.0
# input 765 = 0.0
# input 766 = 0.0
# input 767 = 0.0
# input 768 = 0.0
# input 769 = 0.0
# input 770 = 0.0
# input 771 = 0.0
# input 772 = 0.0
# input 773 = 0.0
# input 774 = 0.0
# input 775 = 0.0
# input 776 = 0.0
# input 777 = 0.0
# input 778 = 0.0
# input 779 = 0.0
# input 780 = 0.0
# input 781 = 0.0
# input 782 = 0.0
# input 783 = 0.0
# output 0 = -0.7069866192913372
# output 1 = -1.7616831787999496
# output 2 = 2.427434123465607
# output 3 = -0.40056523193679033
# output 4 = -3.5867688424539006
# output 5 = 0.31089366458175166
# output 6 = 2.427534123465607
# output 7 = -2.7632576525298362
# output 8 = -1.8034645829652418
# output 9 = -5.988066539764188
# unsat
# unsat
